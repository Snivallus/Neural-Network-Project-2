# %% [markdown]
# ## 1.准备阶段
# 训练数据集 `train_set` 以及测试数据集 `test_set`
# 创建 `train_loader` 和 `test_loader` 用于训练以及测试过程的数据加载

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import torchvision
import torchvision.transforms as transforms
import torch

# PyTorch device
print("CUDA Device Count:", torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    print(f"Device {i} Name:", torch.cuda.get_device_name(i))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"正在使用的是: {device}")

# 创建一个transform, 将 PIL 图片转换为 Tensor
transform = transforms.Compose([
    transforms.ToTensor()
])

# 自定义的帮助函数
from utils.helper_functions import * 

# 下载并加载 CIFAR-10 训练集
# root: 数据集存放路径 (如果路径不存在会自动创建)
# train=True: 指明要加载训练集
# download=True: 如果本地没有, 会自动从网络下载
# transform=transform: 对每张图片应用上面定义的 transform (即 ToTensor)
CIFAR10_trainset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# 同理, 下载并加载 CIFAR-10 测试集
# train=False: 指明要加载测试集
CIFAR10_testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# 调用 get_stats 计算训练集的通道均值和标准差
CIFAR_MEAN_TRAIN, CIFAR_STD_TRAIN = get_stats(CIFAR10_trainset)
print(f"CIFAR Train Set Mean: {CIFAR_MEAN_TRAIN[0]:.4f}, {CIFAR_MEAN_TRAIN[1]:.4f}, {CIFAR_MEAN_TRAIN[2]:.4f}")
print(f"CIFAR Train Set Std: {CIFAR_STD_TRAIN[0]:.4f}, {CIFAR_STD_TRAIN[1]:.4f}, {CIFAR_STD_TRAIN[2]:.4f}")

# 调用 get_stats 计算测试集的通道均值和标准差
CIFAR_MEAN_TEST, CIFAR_STD_TEST = get_stats(CIFAR10_testset)
print(f"CIFAR Test Set Mean: {CIFAR_MEAN_TEST[0]:.4f}, {CIFAR_MEAN_TEST[1]:.4f}, {CIFAR_MEAN_TEST[2]:.4f}")
print(f"CIFAR Test Set Std: {CIFAR_STD_TEST[0]:.4f}, {CIFAR_STD_TEST[1]:.4f}, {CIFAR_STD_TEST[2]:.4f}")
# Out:
# CUDA Device Count: 1
# Device 0 Name: NVIDIA RTX A6000
# 正在使用的是: cuda
# CIFAR Train Set Mean: 0.4914, 0.4822, 0.4465
# CIFAR Train Set Std: 0.2470, 0.2435, 0.2616
# CIFAR Test Set Mean: 0.4942, 0.4851, 0.4504
# CIFAR Test Set Std: 0.2467, 0.2429, 0.2616

# %%
import numpy as np
import random
from torch.utils.data import ConcatDataset

# Set seed
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
     torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Data transforms (normalization & data augmentation)
STATS_TRAIN = (CIFAR_MEAN_TRAIN, CIFAR_STD_TRAIN)
STATS_TEST = (CIFAR_MEAN_TEST, CIFAR_STD_TEST)
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(*STATS_TRAIN),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*STATS_TEST)
])

# PyTorch datasets
train_set = torchvision.datasets.CIFAR10(
    root='./data', 
    train=True, 
    download=True, 
    transform=train_transform
)
test_set = torchvision.datasets.CIFAR10(
    root='./data', 
    train=False, 
    download=True, 
    transform=test_transform
)

classes = train_set.classes
print(classes)

batch_size = 256
train_set_doubled = ConcatDataset([train_set, train_set])
train_loader = torch.utils.data.DataLoader(
    train_set_doubled, 
    batch_size=batch_size, 
    shuffle=True, 
    pin_memory=True, # 异步复制
    num_workers=2
)
train_loader = DeviceDataLoader(train_loader, device)

test_loader = torch.utils.data.DataLoader(
    test_set, 
    batch_size=batch_size*2, 
    shuffle=False, 
    pin_memory=True, # 异步复制
    num_workers=2
)
test_loader = DeviceDataLoader(test_loader, device)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

# Assuming train_loader and classes have been defined
print("显示一些训练图像:")
show_batch_images(
    train_loader, 
    classes, 
    batch_size, 
    CIFAR_MEAN_TRAIN, 
    CIFAR_STD_TRAIN
)

print("显示一些测试图像:")
show_batch_images(
    test_loader, 
    classes, 
    batch_size, 
    CIFAR_MEAN_TEST, 
    CIFAR_STD_TEST
)
# Out:
# 显示一些训练图像:
# Labels: frog  cat   cat   deer  cat   ship  automobile bird  ship  dog   airplane automobile dog   deer  horse frog  frog  airplane deer  frog  automobile cat   dog   ship  dog   frog  automobile bird  frog  automobile frog  automobile cat   dog   deer  automobile automobile ship  frog  cat   automobile cat   cat   deer  dog   truck deer  deer  automobile automobile dog   bird  frog  bird  cat   deer  automobile ship  cat   bird  dog   cat   dog   automobile airplane deer  cat   truck deer  ship  dog   dog   ship  cat   automobile frog  automobile frog  horse horse dog   bird  truck cat   truck ship  airplane ship  airplane airplane dog   automobile cat   frog  dog   bird  ship  automobile bird  bird  airplane bird  horse truck horse truck ship  frog  dog   airplane ship  bird  horse ship  automobile horse automobile dog   ship  ship  bird  frog  bird  bird  deer  automobile airplane bird  horse ship  deer  ship  dog   airplane ship  ship  airplane airplane deer  ship  horse airplane bird  ship  ship  automobile cat   frog  ship  frog  ship  bird  cat   horse frog  automobile automobile deer  dog   automobile cat   ship  deer  automobile bird  airplane truck deer  automobile dog   airplane horse cat   ship  frog  frog  deer  deer  ship  horse frog  cat   bird  ship  truck frog  horse deer  horse airplane horse horse bird  cat   cat   deer  dog   truck airplane deer  airplane frog  frog  truck automobile deer  truck frog  bird  frog  frog  horse truck deer  ship  bird  frog  horse frog  airplane truck dog   frog  bird  airplane truck horse deer  frog  truck ship  horse dog   frog  deer  dog   airplane automobile dog   airplane airplane truck automobile truck cat   bird  bird  cat   cat   ship  ship  horse ship  automobile automobile airplane
# 显示一些测试图像:
# Labels: cat   ship  ship  airplane frog  frog  automobile frog  cat   automobile airplane truck dog   horse truck ship  dog   horse ship  frog  horse airplane deer  truck dog   bird  deer  airplane truck frog  frog  dog   deer  dog   truck bird  deer  automobile truck dog   deer  frog  dog   frog  airplane truck cat   truck horse frog  truck ship  airplane cat   ship  ship  horse horse deer  frog  horse cat   frog  cat   frog  bird  automobile bird  cat   horse bird  frog  ship  ship  airplane bird  truck cat   cat   ship  ship  automobile automobile horse bird  dog   bird  horse ship  truck airplane cat   ship  frog  deer  frog  frog  airplane airplane horse deer  dog   frog  cat   automobile automobile cat   frog  ship  horse deer  airplane frog  bird  automobile cat   airplane deer  bird  horse ship  cat   automobile bird  ship  airplane ship  cat   dog   bird  deer  automobile ship  truck automobile bird  truck horse bird  truck frog  dog   frog  cat   ship  horse frog  bird  dog   bird  ship  truck frog  airplane airplane dog   bird  truck dog   deer  bird  automobile frog  frog  ship  deer  ship  deer  dog   airplane truck truck truck ship  truck truck cat   horse dog   airplane airplane dog   bird  bird  cat   ship  frog  cat   deer  airplane dog   ship  airplane automobile horse bird  ship  ship  horse ship  dog   automobile ship  horse automobile cat   airplane dog   horse truck horse deer  dog   truck ship  airplane horse truck ship  bird  horse frog  truck deer  cat   truck frog  deer  horse frog  dog   automobile dog   ship  ship  airplane deer  airplane dog   dog   automobile automobile ship  truck airplane cat   automobile truck bird  bird  dog   cat   truck truck deer  airplane

# %% [markdown]
# ## 2.创建分类器

# %%
model_0 = to_device(CNN_model(num_blocks=7), device)
# print(model_0)

# 输出模型的参数量、FLOPs、所占空间大小
model_info(model_0, device)
# Out:
# 模型参数量为: 675835
# FLOPs: 0.099 GFLOPs
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.30
# Params size (MB): 2.58
# Estimated Total Size (MB): 13.89

# %%
model_1 = to_device(CNN_model(num_blocks=8), device)
# print(model_1)

# 输出模型的参数量、FLOPs、所占空间大小
model_info(model_1, device)
# Out:
# 模型参数量为: 773842
# FLOPs: 0.114 GFLOPs
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.84
# Params size (MB): 2.95
# Estimated Total Size (MB): 15.80

# %%
model_2 = to_device(CNN_model(num_blocks=9), device)
# print(model_2)

# 输出模型的参数量、FLOPs、所占空间大小
model_info(model_2, device)
# Out:
# 模型参数量为: 871849
# FLOPs: 0.128 GFLOPs
# Input size (MB): 0.01
# Forward/backward pass size (MB): 14.37
# Params size (MB): 3.33
# Estimated Total Size (MB): 17.71

# %% [markdown]
# ## 3.训练

# %%
# 设置超参数
epochs = 100
warmup_epochs = 5
max_lr = 0.001
grad_clip = 1
weight_decay = 1e-4
# 提前停止策略的参数
patience = 10
min_delta = 0.0001

# %%
# 最优模型的保存路径
best_model_path_0 = "./saved_weights/different_structure/best_model_0.pth"

# 检查目录是否存在, 如果不存在, 则创建
if not os.path.exists(os.path.dirname(best_model_path_0)):
    os.makedirs(os.path.dirname(best_model_path_0))

# 计算并输出初始模型(未训练前)的性能
history_0 = [evaluate(model_0, test_loader)]
print(history_0)

# 进行训练
history_0 += fit_with_warmup_adam(
    epochs, max_lr, model_0, train_loader, test_loader,
    weight_decay=weight_decay,
    grad_clip=grad_clip,
    warmup_epochs=warmup_epochs,
    best_model_path=best_model_path_0,
    patience=patience,
    min_delta=min_delta
)
# Out:
# [{'test_loss': 2.302992582321167, 'test_acc': 0.09972426295280457}]
# Epoch [1], learning_rate: 0.00020, train_loss: 2.1387, train_acc: 0.1854, test_loss: 1.7545, test_acc: 0.3390
# New best model saved at epoch 1 with accuracy 0.3390
# Epoch [2], learning_rate: 0.00040, train_loss: 1.7093, train_acc: 0.3649, test_loss: 1.4332, test_acc: 0.4723
# New best model saved at epoch 2 with accuracy 0.4723
# Epoch [3], learning_rate: 0.00060, train_loss: 1.4100, train_acc: 0.4976, test_loss: 1.2361, test_acc: 0.5566
# New best model saved at epoch 3 with accuracy 0.5566
# Epoch [4], learning_rate: 0.00080, train_loss: 1.1983, train_acc: 0.5797, test_loss: 1.1113, test_acc: 0.6078
# New best model saved at epoch 4 with accuracy 0.6078
# Epoch [5], learning_rate: 0.00100, train_loss: 1.0411, train_acc: 0.6390, test_loss: 0.9648, test_acc: 0.6648
# New best model saved at epoch 5 with accuracy 0.6648
# Epoch [6], learning_rate: 0.00100, train_loss: 0.8643, train_acc: 0.7029, test_loss: 0.8658, test_acc: 0.7039
# New best model saved at epoch 6 with accuracy 0.7039
# Epoch [7], learning_rate: 0.00100, train_loss: 0.8029, train_acc: 0.7258, test_loss: 0.9062, test_acc: 0.6953
# Epoch [8], learning_rate: 0.00100, train_loss: 0.7489, train_acc: 0.7460, test_loss: 0.7720, test_acc: 0.7334
# New best model saved at epoch 8 with accuracy 0.7334
# Epoch [9], learning_rate: 0.00100, train_loss: 0.7038, train_acc: 0.7636, test_loss: 1.0022, test_acc: 0.6806
# Epoch [10], learning_rate: 0.00100, train_loss: 0.6652, train_acc: 0.7771, test_loss: 0.6419, test_acc: 0.7783
# New best model saved at epoch 10 with accuracy 0.7783
# Epoch [11], learning_rate: 0.00100, train_loss: 0.6299, train_acc: 0.7883, test_loss: 0.8180, test_acc: 0.7377
# Epoch [12], learning_rate: 0.00100, train_loss: 0.5946, train_acc: 0.8019, test_loss: 0.5995, test_acc: 0.7946
# New best model saved at epoch 12 with accuracy 0.7946
# Epoch [13], learning_rate: 0.00100, train_loss: 0.5632, train_acc: 0.8119, test_loss: 0.6924, test_acc: 0.7710
# Epoch [14], learning_rate: 0.00100, train_loss: 0.5378, train_acc: 0.8202, test_loss: 0.6555, test_acc: 0.7875
# Epoch [15], learning_rate: 0.00100, train_loss: 0.5072, train_acc: 0.8304, test_loss: 0.8640, test_acc: 0.7558
# Epoch [16], learning_rate: 0.00100, train_loss: 0.4892, train_acc: 0.8376, test_loss: 0.6015, test_acc: 0.8072
# New best model saved at epoch 16 with accuracy 0.8072
# Epoch [17], learning_rate: 0.00100, train_loss: 0.4677, train_acc: 0.8440, test_loss: 0.5735, test_acc: 0.8077
# New best model saved at epoch 17 with accuracy 0.8077
# Epoch [18], learning_rate: 0.00100, train_loss: 0.4467, train_acc: 0.8520, test_loss: 0.5177, test_acc: 0.8299
# New best model saved at epoch 18 with accuracy 0.8299
# Epoch [19], learning_rate: 0.00100, train_loss: 0.4223, train_acc: 0.8589, test_loss: 0.5916, test_acc: 0.8114
# Epoch [20], learning_rate: 0.00100, train_loss: 0.4022, train_acc: 0.8655, test_loss: 0.5373, test_acc: 0.8308
# New best model saved at epoch 20 with accuracy 0.8308
# Epoch [21], learning_rate: 0.00100, train_loss: 0.3959, train_acc: 0.8686, test_loss: 0.5164, test_acc: 0.8340
# New best model saved at epoch 21 with accuracy 0.8340
# Epoch [22], learning_rate: 0.00100, train_loss: 0.3805, train_acc: 0.8734, test_loss: 0.5722, test_acc: 0.8196
# Epoch [23], learning_rate: 0.00100, train_loss: 0.3633, train_acc: 0.8793, test_loss: 0.5154, test_acc: 0.8323
# Epoch [24], learning_rate: 0.00100, train_loss: 0.3516, train_acc: 0.8834, test_loss: 0.5597, test_acc: 0.8291
# Epoch [25], learning_rate: 0.00100, train_loss: 0.3361, train_acc: 0.8882, test_loss: 0.5166, test_acc: 0.8411
# New best model saved at epoch 25 with accuracy 0.8411
# Epoch [26], learning_rate: 0.00100, train_loss: 0.3289, train_acc: 0.8917, test_loss: 0.5627, test_acc: 0.8252
# Epoch [27], learning_rate: 0.00100, train_loss: 0.3219, train_acc: 0.8938, test_loss: 0.5007, test_acc: 0.8393
# Epoch [28], learning_rate: 0.00100, train_loss: 0.3144, train_acc: 0.8952, test_loss: 0.5203, test_acc: 0.8425
# New best model saved at epoch 28 with accuracy 0.8425
# Epoch [29], learning_rate: 0.00100, train_loss: 0.3051, train_acc: 0.8993, test_loss: 0.4414, test_acc: 0.8597
# New best model saved at epoch 29 with accuracy 0.8597
# Epoch [30], learning_rate: 0.00099, train_loss: 0.2896, train_acc: 0.9038, test_loss: 0.4517, test_acc: 0.8588
# Epoch [31], learning_rate: 0.00099, train_loss: 0.2826, train_acc: 0.9059, test_loss: 0.4452, test_acc: 0.8616
# New best model saved at epoch 31 with accuracy 0.8616
# Epoch [32], learning_rate: 0.00099, train_loss: 0.2731, train_acc: 0.9091, test_loss: 0.3965, test_acc: 0.8736
# New best model saved at epoch 32 with accuracy 0.8736
# Epoch [33], learning_rate: 0.00098, train_loss: 0.2678, train_acc: 0.9115, test_loss: 0.4286, test_acc: 0.8680
# Epoch [34], learning_rate: 0.00097, train_loss: 0.2639, train_acc: 0.9132, test_loss: 0.5282, test_acc: 0.8505
# Epoch [35], learning_rate: 0.00097, train_loss: 0.2533, train_acc: 0.9176, test_loss: 0.4258, test_acc: 0.8680
# Epoch [36], learning_rate: 0.00096, train_loss: 0.2480, train_acc: 0.9175, test_loss: 0.4339, test_acc: 0.8592
# Epoch [37], learning_rate: 0.00095, train_loss: 0.2386, train_acc: 0.9203, test_loss: 0.4272, test_acc: 0.8713
# Epoch [38], learning_rate: 0.00094, train_loss: 0.2365, train_acc: 0.9207, test_loss: 0.4307, test_acc: 0.8690
# Epoch [39], learning_rate: 0.00093, train_loss: 0.2290, train_acc: 0.9246, test_loss: 0.4020, test_acc: 0.8791
# New best model saved at epoch 39 with accuracy 0.8791
# Epoch [40], learning_rate: 0.00092, train_loss: 0.2231, train_acc: 0.9263, test_loss: 0.4523, test_acc: 0.8622
# Epoch [41], learning_rate: 0.00091, train_loss: 0.2210, train_acc: 0.9267, test_loss: 0.3798, test_acc: 0.8833
# New best model saved at epoch 41 with accuracy 0.8833
# Epoch [42], learning_rate: 0.00090, train_loss: 0.2110, train_acc: 0.9303, test_loss: 0.4292, test_acc: 0.8718
# Epoch [43], learning_rate: 0.00089, train_loss: 0.2086, train_acc: 0.9309, test_loss: 0.4497, test_acc: 0.8692
# Epoch [44], learning_rate: 0.00088, train_loss: 0.2047, train_acc: 0.9323, test_loss: 0.4450, test_acc: 0.8678
# Epoch [45], learning_rate: 0.00086, train_loss: 0.1942, train_acc: 0.9353, test_loss: 0.4184, test_acc: 0.8747
# Epoch [46], learning_rate: 0.00085, train_loss: 0.1886, train_acc: 0.9377, test_loss: 0.4459, test_acc: 0.8764
# Epoch [47], learning_rate: 0.00084, train_loss: 0.1883, train_acc: 0.9381, test_loss: 0.3788, test_acc: 0.8859
# New best model saved at epoch 47 with accuracy 0.8859
# Epoch [48], learning_rate: 0.00082, train_loss: 0.1817, train_acc: 0.9401, test_loss: 0.3989, test_acc: 0.8779
# Epoch [49], learning_rate: 0.00081, train_loss: 0.1778, train_acc: 0.9413, test_loss: 0.3959, test_acc: 0.8850
# Epoch [50], learning_rate: 0.00079, train_loss: 0.1676, train_acc: 0.9447, test_loss: 0.4386, test_acc: 0.8748
# Epoch [51], learning_rate: 0.00078, train_loss: 0.1660, train_acc: 0.9448, test_loss: 0.3804, test_acc: 0.8890
# New best model saved at epoch 51 with accuracy 0.8890
# Epoch [52], learning_rate: 0.00076, train_loss: 0.1575, train_acc: 0.9481, test_loss: 0.4044, test_acc: 0.8845
# Epoch [53], learning_rate: 0.00074, train_loss: 0.1575, train_acc: 0.9478, test_loss: 0.4660, test_acc: 0.8707
# Epoch [54], learning_rate: 0.00072, train_loss: 0.1519, train_acc: 0.9500, test_loss: 0.4654, test_acc: 0.8744
# Epoch [55], learning_rate: 0.00071, train_loss: 0.1455, train_acc: 0.9513, test_loss: 0.3877, test_acc: 0.8900
# New best model saved at epoch 55 with accuracy 0.8900
# Epoch [56], learning_rate: 0.00069, train_loss: 0.1410, train_acc: 0.9527, test_loss: 0.4453, test_acc: 0.8761
# Epoch [57], learning_rate: 0.00067, train_loss: 0.1370, train_acc: 0.9547, test_loss: 0.4205, test_acc: 0.8859
# Epoch [58], learning_rate: 0.00065, train_loss: 0.1339, train_acc: 0.9560, test_loss: 0.3929, test_acc: 0.8900
# Epoch [59], learning_rate: 0.00063, train_loss: 0.1287, train_acc: 0.9568, test_loss: 0.3997, test_acc: 0.8858
# Epoch [60], learning_rate: 0.00062, train_loss: 0.1250, train_acc: 0.9584, test_loss: 0.3971, test_acc: 0.8891
# Epoch [61], learning_rate: 0.00060, train_loss: 0.1174, train_acc: 0.9613, test_loss: 0.3900, test_acc: 0.8918
# New best model saved at epoch 61 with accuracy 0.8918
# Epoch [62], learning_rate: 0.00058, train_loss: 0.1179, train_acc: 0.9616, test_loss: 0.4055, test_acc: 0.8869
# Epoch [63], learning_rate: 0.00056, train_loss: 0.1126, train_acc: 0.9628, test_loss: 0.4004, test_acc: 0.8901
# Epoch [64], learning_rate: 0.00054, train_loss: 0.1072, train_acc: 0.9646, test_loss: 0.4881, test_acc: 0.8790
# Epoch [65], learning_rate: 0.00052, train_loss: 0.1048, train_acc: 0.9657, test_loss: 0.3995, test_acc: 0.8950
# New best model saved at epoch 65 with accuracy 0.8950
# Epoch [66], learning_rate: 0.00050, train_loss: 0.1007, train_acc: 0.9671, test_loss: 0.3888, test_acc: 0.8966
# New best model saved at epoch 66 with accuracy 0.8966
# Epoch [67], learning_rate: 0.00048, train_loss: 0.0950, train_acc: 0.9687, test_loss: 0.4101, test_acc: 0.8937
# Epoch [68], learning_rate: 0.00047, train_loss: 0.0921, train_acc: 0.9697, test_loss: 0.4156, test_acc: 0.8940
# Epoch [69], learning_rate: 0.00045, train_loss: 0.0879, train_acc: 0.9710, test_loss: 0.4416, test_acc: 0.8883
# Epoch [70], learning_rate: 0.00043, train_loss: 0.0849, train_acc: 0.9724, test_loss: 0.3942, test_acc: 0.9011
# New best model saved at epoch 70 with accuracy 0.9011
# Epoch [71], learning_rate: 0.00041, train_loss: 0.0794, train_acc: 0.9744, test_loss: 0.3847, test_acc: 0.9017
# New best model saved at epoch 71 with accuracy 0.9017
# Epoch [72], learning_rate: 0.00039, train_loss: 0.0763, train_acc: 0.9754, test_loss: 0.4199, test_acc: 0.8976
# Epoch [73], learning_rate: 0.00038, train_loss: 0.0731, train_acc: 0.9763, test_loss: 0.4001, test_acc: 0.8993
# Epoch [74], learning_rate: 0.00036, train_loss: 0.0720, train_acc: 0.9766, test_loss: 0.4082, test_acc: 0.8994
# Epoch [75], learning_rate: 0.00034, train_loss: 0.0652, train_acc: 0.9787, test_loss: 0.4159, test_acc: 0.8990
# Epoch [76], learning_rate: 0.00032, train_loss: 0.0643, train_acc: 0.9798, test_loss: 0.4174, test_acc: 0.9012
# Epoch [77], learning_rate: 0.00031, train_loss: 0.0586, train_acc: 0.9807, test_loss: 0.4011, test_acc: 0.9024
# New best model saved at epoch 77 with accuracy 0.9024
# Epoch [78], learning_rate: 0.00029, train_loss: 0.0563, train_acc: 0.9818, test_loss: 0.4202, test_acc: 0.9005
# Epoch [79], learning_rate: 0.00028, train_loss: 0.0529, train_acc: 0.9830, test_loss: 0.4155, test_acc: 0.9019
# Epoch [80], learning_rate: 0.00026, train_loss: 0.0507, train_acc: 0.9839, test_loss: 0.4382, test_acc: 0.8990
# Epoch [81], learning_rate: 0.00025, train_loss: 0.0459, train_acc: 0.9853, test_loss: 0.4353, test_acc: 0.9015
# Epoch [82], learning_rate: 0.00024, train_loss: 0.0459, train_acc: 0.9852, test_loss: 0.4362, test_acc: 0.9047
# New best model saved at epoch 82 with accuracy 0.9047
# Epoch [83], learning_rate: 0.00022, train_loss: 0.0421, train_acc: 0.9866, test_loss: 0.4458, test_acc: 0.9054
# New best model saved at epoch 83 with accuracy 0.9054
# Epoch [84], learning_rate: 0.00021, train_loss: 0.0396, train_acc: 0.9876, test_loss: 0.4530, test_acc: 0.9041
# Epoch [85], learning_rate: 0.00020, train_loss: 0.0375, train_acc: 0.9878, test_loss: 0.4552, test_acc: 0.9052
# Epoch [86], learning_rate: 0.00019, train_loss: 0.0359, train_acc: 0.9886, test_loss: 0.4486, test_acc: 0.9043
# Epoch [87], learning_rate: 0.00018, train_loss: 0.0339, train_acc: 0.9896, test_loss: 0.4552, test_acc: 0.9055
# Epoch [88], learning_rate: 0.00017, train_loss: 0.0322, train_acc: 0.9899, test_loss: 0.4497, test_acc: 0.9036
# Epoch [89], learning_rate: 0.00016, train_loss: 0.0311, train_acc: 0.9899, test_loss: 0.4418, test_acc: 0.9076
# New best model saved at epoch 89 with accuracy 0.9076
# Epoch [90], learning_rate: 0.00015, train_loss: 0.0269, train_acc: 0.9915, test_loss: 0.4555, test_acc: 0.9064
# Epoch [91], learning_rate: 0.00014, train_loss: 0.0285, train_acc: 0.9912, test_loss: 0.4407, test_acc: 0.9082
# New best model saved at epoch 91 with accuracy 0.9082
# Epoch [92], learning_rate: 0.00013, train_loss: 0.0253, train_acc: 0.9923, test_loss: 0.4700, test_acc: 0.9055
# Epoch [93], learning_rate: 0.00013, train_loss: 0.0251, train_acc: 0.9924, test_loss: 0.4618, test_acc: 0.9085
# New best model saved at epoch 93 with accuracy 0.9085
# Epoch [94], learning_rate: 0.00012, train_loss: 0.0228, train_acc: 0.9929, test_loss: 0.4767, test_acc: 0.9073
# Epoch [95], learning_rate: 0.00011, train_loss: 0.0233, train_acc: 0.9927, test_loss: 0.4551, test_acc: 0.9107
# New best model saved at epoch 95 with accuracy 0.9107
# Epoch [96], learning_rate: 0.00011, train_loss: 0.0217, train_acc: 0.9934, test_loss: 0.4625, test_acc: 0.9103
# Epoch [97], learning_rate: 0.00011, train_loss: 0.0193, train_acc: 0.9939, test_loss: 0.4778, test_acc: 0.9080
# Epoch [98], learning_rate: 0.00010, train_loss: 0.0193, train_acc: 0.9942, test_loss: 0.4855, test_acc: 0.9082
# Epoch [99], learning_rate: 0.00010, train_loss: 0.0205, train_acc: 0.9936, test_loss: 0.4717, test_acc: 0.9098
# Epoch [100], learning_rate: 0.00010, train_loss: 0.0201, train_acc: 0.9940, test_loss: 0.4725, test_acc: 0.9078

# %%
# 最优模型的保存路径
best_model_path_1 = "./saved_weights/different_structure/best_model_1.pth"

# 检查目录是否存在, 如果不存在, 则创建
if not os.path.exists(os.path.dirname(best_model_path_1)):
    os.makedirs(os.path.dirname(best_model_path_1))

# 计算并输出初始模型(未训练前)的性能
history_1 = [evaluate(model_1, test_loader)]
print(history_1)

# 进行训练
history_1 += fit_with_warmup_adam(
    epochs, max_lr, model_1, train_loader, test_loader,
    weight_decay=weight_decay,
    grad_clip=grad_clip,
    warmup_epochs=warmup_epochs,
    best_model_path=best_model_path_1,
    patience=patience,
    min_delta=min_delta
)
# Out:
# [{'test_loss': 2.303490400314331, 'test_acc': 0.10006894171237946}]
# Epoch [1], learning_rate: 0.00020, train_loss: 2.1173, train_acc: 0.1883, test_loss: 1.7881, test_acc: 0.3310
# New best model saved at epoch 1 with accuracy 0.3310
# Epoch [2], learning_rate: 0.00040, train_loss: 1.7629, train_acc: 0.3404, test_loss: 1.5733, test_acc: 0.4231
# New best model saved at epoch 2 with accuracy 0.4231
# Epoch [3], learning_rate: 0.00060, train_loss: 1.5079, train_acc: 0.4598, test_loss: 1.3032, test_acc: 0.5393
# New best model saved at epoch 3 with accuracy 0.5393
# Epoch [4], learning_rate: 0.00080, train_loss: 1.2818, train_acc: 0.5497, test_loss: 1.1805, test_acc: 0.5879
# New best model saved at epoch 4 with accuracy 0.5879
# Epoch [5], learning_rate: 0.00100, train_loss: 1.1110, train_acc: 0.6133, test_loss: 1.2315, test_acc: 0.5932
# New best model saved at epoch 5 with accuracy 0.5932
# Epoch [6], learning_rate: 0.00100, train_loss: 0.9258, train_acc: 0.6800, test_loss: 0.8593, test_acc: 0.6968
# New best model saved at epoch 6 with accuracy 0.6968
# Epoch [7], learning_rate: 0.00100, train_loss: 0.8497, train_acc: 0.7100, test_loss: 0.9057, test_acc: 0.6838
# Epoch [8], learning_rate: 0.00100, train_loss: 0.7928, train_acc: 0.7310, test_loss: 0.7654, test_acc: 0.7403
# New best model saved at epoch 8 with accuracy 0.7403
# Epoch [9], learning_rate: 0.00100, train_loss: 0.7381, train_acc: 0.7524, test_loss: 0.7981, test_acc: 0.7265
# Epoch [10], learning_rate: 0.00100, train_loss: 0.6933, train_acc: 0.7670, test_loss: 0.7279, test_acc: 0.7544
# New best model saved at epoch 10 with accuracy 0.7544
# Epoch [11], learning_rate: 0.00100, train_loss: 0.6492, train_acc: 0.7832, test_loss: 0.7348, test_acc: 0.7534
# Epoch [12], learning_rate: 0.00100, train_loss: 0.6095, train_acc: 0.7974, test_loss: 0.8839, test_acc: 0.7195
# Epoch [13], learning_rate: 0.00100, train_loss: 0.5755, train_acc: 0.8081, test_loss: 0.7091, test_acc: 0.7563
# New best model saved at epoch 13 with accuracy 0.7563
# Epoch [14], learning_rate: 0.00100, train_loss: 0.5418, train_acc: 0.8197, test_loss: 0.6535, test_acc: 0.7840
# New best model saved at epoch 14 with accuracy 0.7840
# Epoch [15], learning_rate: 0.00100, train_loss: 0.5100, train_acc: 0.8310, test_loss: 0.6908, test_acc: 0.7830
# Epoch [16], learning_rate: 0.00100, train_loss: 0.4855, train_acc: 0.8388, test_loss: 0.5787, test_acc: 0.8092
# New best model saved at epoch 16 with accuracy 0.8092
# Epoch [17], learning_rate: 0.00100, train_loss: 0.4620, train_acc: 0.8460, test_loss: 0.5335, test_acc: 0.8236
# New best model saved at epoch 17 with accuracy 0.8236
# Epoch [18], learning_rate: 0.00100, train_loss: 0.4380, train_acc: 0.8537, test_loss: 0.6238, test_acc: 0.7961
# Epoch [19], learning_rate: 0.00100, train_loss: 0.4141, train_acc: 0.8619, test_loss: 0.6330, test_acc: 0.8013
# Epoch [20], learning_rate: 0.00100, train_loss: 0.3985, train_acc: 0.8675, test_loss: 0.4871, test_acc: 0.8377
# New best model saved at epoch 20 with accuracy 0.8377
# Epoch [21], learning_rate: 0.00100, train_loss: 0.3820, train_acc: 0.8730, test_loss: 0.5156, test_acc: 0.8318
# Epoch [22], learning_rate: 0.00100, train_loss: 0.3706, train_acc: 0.8777, test_loss: 0.4715, test_acc: 0.8510
# New best model saved at epoch 22 with accuracy 0.8510
# Epoch [23], learning_rate: 0.00100, train_loss: 0.3489, train_acc: 0.8843, test_loss: 0.4838, test_acc: 0.8466
# Epoch [24], learning_rate: 0.00100, train_loss: 0.3417, train_acc: 0.8860, test_loss: 0.5169, test_acc: 0.8397
# Epoch [25], learning_rate: 0.00100, train_loss: 0.3273, train_acc: 0.8924, test_loss: 0.5081, test_acc: 0.8421
# Epoch [26], learning_rate: 0.00100, train_loss: 0.3194, train_acc: 0.8941, test_loss: 0.4735, test_acc: 0.8505
# Epoch [27], learning_rate: 0.00100, train_loss: 0.3092, train_acc: 0.8985, test_loss: 0.5415, test_acc: 0.8342
# Epoch [28], learning_rate: 0.00100, train_loss: 0.2947, train_acc: 0.9025, test_loss: 0.4690, test_acc: 0.8517
# New best model saved at epoch 28 with accuracy 0.8517
# Epoch [29], learning_rate: 0.00100, train_loss: 0.2896, train_acc: 0.9051, test_loss: 0.5701, test_acc: 0.8264
# Epoch [30], learning_rate: 0.00099, train_loss: 0.2785, train_acc: 0.9083, test_loss: 0.5437, test_acc: 0.8384
# Epoch [31], learning_rate: 0.00099, train_loss: 0.2712, train_acc: 0.9099, test_loss: 0.4914, test_acc: 0.8510
# Epoch [32], learning_rate: 0.00099, train_loss: 0.2620, train_acc: 0.9140, test_loss: 0.5443, test_acc: 0.8402
# Epoch [33], learning_rate: 0.00098, train_loss: 0.2561, train_acc: 0.9154, test_loss: 0.4327, test_acc: 0.8723
# New best model saved at epoch 33 with accuracy 0.8723
# Epoch [34], learning_rate: 0.00097, train_loss: 0.2470, train_acc: 0.9177, test_loss: 0.5100, test_acc: 0.8449
# Epoch [35], learning_rate: 0.00097, train_loss: 0.2413, train_acc: 0.9208, test_loss: 0.3770, test_acc: 0.8817
# New best model saved at epoch 35 with accuracy 0.8817
# Epoch [36], learning_rate: 0.00096, train_loss: 0.2329, train_acc: 0.9223, test_loss: 0.4176, test_acc: 0.8702
# Epoch [37], learning_rate: 0.00095, train_loss: 0.2248, train_acc: 0.9261, test_loss: 0.4278, test_acc: 0.8702
# Epoch [38], learning_rate: 0.00094, train_loss: 0.2191, train_acc: 0.9276, test_loss: 0.4973, test_acc: 0.8534
# Epoch [39], learning_rate: 0.00093, train_loss: 0.2168, train_acc: 0.9286, test_loss: 0.3952, test_acc: 0.8759
# Epoch [40], learning_rate: 0.00092, train_loss: 0.2106, train_acc: 0.9306, test_loss: 0.4114, test_acc: 0.8698
# Epoch [41], learning_rate: 0.00091, train_loss: 0.2017, train_acc: 0.9333, test_loss: 0.4300, test_acc: 0.8704
# Epoch [42], learning_rate: 0.00090, train_loss: 0.1991, train_acc: 0.9342, test_loss: 0.4237, test_acc: 0.8756
# Epoch [43], learning_rate: 0.00089, train_loss: 0.1969, train_acc: 0.9350, test_loss: 0.4157, test_acc: 0.8751
# Epoch [44], learning_rate: 0.00088, train_loss: 0.1901, train_acc: 0.9372, test_loss: 0.4088, test_acc: 0.8804
# Epoch [45], learning_rate: 0.00086, train_loss: 0.1845, train_acc: 0.9393, test_loss: 0.4125, test_acc: 0.8812
# Early stopping triggered after epoch 45
# Best accuracy 0.8816809058189392 occurred at epoch 35
# Early stopping——training halted.

# %%
# 最优模型的保存路径
best_model_path_2 = "./saved_weights/different_structure/best_model_2.pth"

# 检查目录是否存在, 如果不存在, 则创建
if not os.path.exists(os.path.dirname(best_model_path_2)):
    os.makedirs(os.path.dirname(best_model_path_2))

# 计算并输出初始模型(未训练前)的性能
history_2 = [evaluate(model_2, test_loader)]
print(history_2)

# 进行训练
history_2 += fit_with_warmup_adam(
    epochs, max_lr, model_2, train_loader, test_loader,
    weight_decay=weight_decay,
    grad_clip=grad_clip,
    warmup_epochs=warmup_epochs,
    best_model_path=best_model_path_2,
    patience=patience,
    min_delta=min_delta
)
# Out:
# [{'test_loss': 2.3031466007232666, 'test_acc': 0.10015510767698288}]
# Epoch [1], learning_rate: 0.00020, train_loss: 2.1807, train_acc: 0.1660, test_loss: 1.8827, test_acc: 0.2704
# New best model saved at epoch 1 with accuracy 0.2704
# Epoch [2], learning_rate: 0.00040, train_loss: 1.8386, train_acc: 0.3023, test_loss: 1.6736, test_acc: 0.3809
# New best model saved at epoch 2 with accuracy 0.3809
# Epoch [3], learning_rate: 0.00060, train_loss: 1.6303, train_acc: 0.4013, test_loss: 1.4604, test_acc: 0.4726
# New best model saved at epoch 3 with accuracy 0.4726
# Epoch [4], learning_rate: 0.00080, train_loss: 1.4353, train_acc: 0.4867, test_loss: 1.3744, test_acc: 0.5158
# New best model saved at epoch 4 with accuracy 0.5158
# Epoch [5], learning_rate: 0.00100, train_loss: 1.2421, train_acc: 0.5621, test_loss: 1.4443, test_acc: 0.5246
# New best model saved at epoch 5 with accuracy 0.5246
# Epoch [6], learning_rate: 0.00100, train_loss: 1.0404, train_acc: 0.6357, test_loss: 1.0042, test_acc: 0.6445
# New best model saved at epoch 6 with accuracy 0.6445
# Epoch [7], learning_rate: 0.00100, train_loss: 0.9731, train_acc: 0.6625, test_loss: 0.8833, test_acc: 0.6875
# New best model saved at epoch 7 with accuracy 0.6875
# Epoch [8], learning_rate: 0.00100, train_loss: 0.9133, train_acc: 0.6872, test_loss: 0.9282, test_acc: 0.6829
# Epoch [9], learning_rate: 0.00100, train_loss: 0.8617, train_acc: 0.7078, test_loss: 0.8124, test_acc: 0.7186
# New best model saved at epoch 9 with accuracy 0.7186
# Epoch [10], learning_rate: 0.00100, train_loss: 0.8094, train_acc: 0.7260, test_loss: 0.8785, test_acc: 0.7004
# Epoch [11], learning_rate: 0.00100, train_loss: 0.7645, train_acc: 0.7421, test_loss: 0.7849, test_acc: 0.7285
# New best model saved at epoch 11 with accuracy 0.7285
# Epoch [12], learning_rate: 0.00100, train_loss: 0.7207, train_acc: 0.7579, test_loss: 0.7039, test_acc: 0.7545
# New best model saved at epoch 12 with accuracy 0.7545
# Epoch [13], learning_rate: 0.00100, train_loss: 0.6770, train_acc: 0.7724, test_loss: 0.8321, test_acc: 0.7338
# Epoch [14], learning_rate: 0.00100, train_loss: 0.6434, train_acc: 0.7852, test_loss: 0.7584, test_acc: 0.7499
# Epoch [15], learning_rate: 0.00100, train_loss: 0.6043, train_acc: 0.7979, test_loss: 0.6824, test_acc: 0.7765
# New best model saved at epoch 15 with accuracy 0.7765
# Epoch [16], learning_rate: 0.00100, train_loss: 0.5639, train_acc: 0.8115, test_loss: 1.0610, test_acc: 0.6895
# Epoch [17], learning_rate: 0.00100, train_loss: 0.5385, train_acc: 0.8205, test_loss: 0.5716, test_acc: 0.8115
# New best model saved at epoch 17 with accuracy 0.8115
# Epoch [18], learning_rate: 0.00100, train_loss: 0.5072, train_acc: 0.8316, test_loss: 0.6919, test_acc: 0.7806
# Epoch [19], learning_rate: 0.00100, train_loss: 0.4926, train_acc: 0.8364, test_loss: 0.9766, test_acc: 0.7213
# Epoch [20], learning_rate: 0.00100, train_loss: 0.4649, train_acc: 0.8449, test_loss: 0.5209, test_acc: 0.8275
# New best model saved at epoch 20 with accuracy 0.8275
# Epoch [21], learning_rate: 0.00100, train_loss: 0.4414, train_acc: 0.8533, test_loss: 0.6029, test_acc: 0.8157
# Epoch [22], learning_rate: 0.00100, train_loss: 0.4255, train_acc: 0.8593, test_loss: 0.6803, test_acc: 0.7849
# Epoch [23], learning_rate: 0.00100, train_loss: 0.4100, train_acc: 0.8650, test_loss: 0.5390, test_acc: 0.8188
# Epoch [24], learning_rate: 0.00100, train_loss: 0.3958, train_acc: 0.8697, test_loss: 0.5936, test_acc: 0.8107
# Epoch [25], learning_rate: 0.00100, train_loss: 0.3788, train_acc: 0.8740, test_loss: 0.5082, test_acc: 0.8340
# New best model saved at epoch 25 with accuracy 0.8340
# Epoch [26], learning_rate: 0.00100, train_loss: 0.3681, train_acc: 0.8782, test_loss: 0.4485, test_acc: 0.8483
# New best model saved at epoch 26 with accuracy 0.8483
# Epoch [27], learning_rate: 0.00100, train_loss: 0.3529, train_acc: 0.8825, test_loss: 0.6361, test_acc: 0.8106
# Epoch [28], learning_rate: 0.00100, train_loss: 0.3424, train_acc: 0.8864, test_loss: 0.4345, test_acc: 0.8589
# New best model saved at epoch 28 with accuracy 0.8589
# Epoch [29], learning_rate: 0.00100, train_loss: 0.3333, train_acc: 0.8892, test_loss: 0.5680, test_acc: 0.8293
# Epoch [30], learning_rate: 0.00099, train_loss: 0.3185, train_acc: 0.8937, test_loss: 0.4555, test_acc: 0.8569
# Epoch [31], learning_rate: 0.00099, train_loss: 0.3127, train_acc: 0.8971, test_loss: 0.5669, test_acc: 0.8289
# Epoch [32], learning_rate: 0.00099, train_loss: 0.3064, train_acc: 0.8990, test_loss: 0.5926, test_acc: 0.8159
# Epoch [33], learning_rate: 0.00098, train_loss: 0.2943, train_acc: 0.9016, test_loss: 0.4712, test_acc: 0.8493
# Epoch [34], learning_rate: 0.00097, train_loss: 0.2846, train_acc: 0.9057, test_loss: 0.4217, test_acc: 0.8709
# New best model saved at epoch 34 with accuracy 0.8709
# Epoch [35], learning_rate: 0.00097, train_loss: 0.2801, train_acc: 0.9069, test_loss: 0.4181, test_acc: 0.8680
# Epoch [36], learning_rate: 0.00096, train_loss: 0.2716, train_acc: 0.9098, test_loss: 0.5537, test_acc: 0.8352
# Epoch [37], learning_rate: 0.00095, train_loss: 0.2645, train_acc: 0.9130, test_loss: 0.5928, test_acc: 0.8315
# Epoch [38], learning_rate: 0.00094, train_loss: 0.2574, train_acc: 0.9148, test_loss: 0.3994, test_acc: 0.8738
# New best model saved at epoch 38 with accuracy 0.8738
# Epoch [39], learning_rate: 0.00093, train_loss: 0.2502, train_acc: 0.9168, test_loss: 0.4857, test_acc: 0.8555
# Epoch [40], learning_rate: 0.00092, train_loss: 0.2448, train_acc: 0.9183, test_loss: 0.3844, test_acc: 0.8795
# New best model saved at epoch 40 with accuracy 0.8795
# Epoch [41], learning_rate: 0.00091, train_loss: 0.2357, train_acc: 0.9213, test_loss: 0.5600, test_acc: 0.8390
# Epoch [42], learning_rate: 0.00090, train_loss: 0.2304, train_acc: 0.9226, test_loss: 0.4477, test_acc: 0.8637
# Epoch [43], learning_rate: 0.00089, train_loss: 0.2237, train_acc: 0.9258, test_loss: 0.4766, test_acc: 0.8606
# Epoch [44], learning_rate: 0.00088, train_loss: 0.2177, train_acc: 0.9284, test_loss: 0.3644, test_acc: 0.8853
# New best model saved at epoch 44 with accuracy 0.8853
# Epoch [45], learning_rate: 0.00086, train_loss: 0.2096, train_acc: 0.9304, test_loss: 0.4235, test_acc: 0.8757
# Epoch [46], learning_rate: 0.00085, train_loss: 0.2066, train_acc: 0.9308, test_loss: 0.4266, test_acc: 0.8736
# Epoch [47], learning_rate: 0.00084, train_loss: 0.2004, train_acc: 0.9335, test_loss: 0.4172, test_acc: 0.8745
# Epoch [48], learning_rate: 0.00082, train_loss: 0.1935, train_acc: 0.9366, test_loss: 0.4343, test_acc: 0.8684
# Epoch [49], learning_rate: 0.00081, train_loss: 0.1884, train_acc: 0.9372, test_loss: 0.4458, test_acc: 0.8731
# Epoch [50], learning_rate: 0.00079, train_loss: 0.1839, train_acc: 0.9387, test_loss: 0.3753, test_acc: 0.8882
# New best model saved at epoch 50 with accuracy 0.8882
# Epoch [51], learning_rate: 0.00078, train_loss: 0.1788, train_acc: 0.9407, test_loss: 0.4073, test_acc: 0.8786
# Epoch [52], learning_rate: 0.00076, train_loss: 0.1712, train_acc: 0.9430, test_loss: 0.3784, test_acc: 0.8860
# Epoch [53], learning_rate: 0.00074, train_loss: 0.1685, train_acc: 0.9445, test_loss: 0.4066, test_acc: 0.8800
# Epoch [54], learning_rate: 0.00072, train_loss: 0.1617, train_acc: 0.9462, test_loss: 0.3683, test_acc: 0.8917
# New best model saved at epoch 54 with accuracy 0.8917
# Epoch [55], learning_rate: 0.00071, train_loss: 0.1567, train_acc: 0.9475, test_loss: 0.3728, test_acc: 0.8921
# New best model saved at epoch 55 with accuracy 0.8921
# Epoch [56], learning_rate: 0.00069, train_loss: 0.1528, train_acc: 0.9492, test_loss: 0.3537, test_acc: 0.8968
# New best model saved at epoch 56 with accuracy 0.8968
# Epoch [57], learning_rate: 0.00067, train_loss: 0.1479, train_acc: 0.9511, test_loss: 0.3682, test_acc: 0.8962
# Epoch [58], learning_rate: 0.00065, train_loss: 0.1442, train_acc: 0.9523, test_loss: 0.3809, test_acc: 0.8894
# Epoch [59], learning_rate: 0.00063, train_loss: 0.1360, train_acc: 0.9550, test_loss: 0.3802, test_acc: 0.8939
# Epoch [60], learning_rate: 0.00062, train_loss: 0.1322, train_acc: 0.9567, test_loss: 0.4316, test_acc: 0.8829
# Epoch [61], learning_rate: 0.00060, train_loss: 0.1304, train_acc: 0.9572, test_loss: 0.3638, test_acc: 0.8995
# New best model saved at epoch 61 with accuracy 0.8995
# Epoch [62], learning_rate: 0.00058, train_loss: 0.1232, train_acc: 0.9595, test_loss: 0.4099, test_acc: 0.8881
# Epoch [63], learning_rate: 0.00056, train_loss: 0.1197, train_acc: 0.9604, test_loss: 0.4189, test_acc: 0.8891
# Epoch [64], learning_rate: 0.00054, train_loss: 0.1165, train_acc: 0.9613, test_loss: 0.4398, test_acc: 0.8846
# Epoch [65], learning_rate: 0.00052, train_loss: 0.1114, train_acc: 0.9634, test_loss: 0.3840, test_acc: 0.8950
# Epoch [66], learning_rate: 0.00050, train_loss: 0.1081, train_acc: 0.9642, test_loss: 0.3807, test_acc: 0.8995
# Epoch [67], learning_rate: 0.00048, train_loss: 0.1025, train_acc: 0.9664, test_loss: 0.4030, test_acc: 0.8919
# Epoch [68], learning_rate: 0.00047, train_loss: 0.0971, train_acc: 0.9682, test_loss: 0.4149, test_acc: 0.8950
# Epoch [69], learning_rate: 0.00045, train_loss: 0.0935, train_acc: 0.9689, test_loss: 0.4093, test_acc: 0.8916
# Epoch [70], learning_rate: 0.00043, train_loss: 0.0899, train_acc: 0.9703, test_loss: 0.3826, test_acc: 0.8989
# Epoch [71], learning_rate: 0.00041, train_loss: 0.0860, train_acc: 0.9724, test_loss: 0.4030, test_acc: 0.8976
# Early stopping triggered after epoch 71
# Best accuracy 0.8995060324668884 occurred at epoch 61
# Early stopping——training halted.

# %% [markdown]
# ## 4.模型性能

# %% [markdown]
# ### (1) 基础学习率变化

# %%
# 绘制模型基础学习率变化
lr = np.concatenate([x.get('lrs', []) for x in history_0])
plt.plot(lr, '-b')
plt.xlabel('epoch')
plt.ylabel('learning rate')
plt.title('Learning Rate vs. No. of epochs')
# plt.savefig('./figures/learning_rate.pdf')
plt.show()

# %% [markdown]
# ### (2) 准确率

# %%
# 绘制 history_0
plot_accuracies(history_0)
plot_log_loss(history_0)

# %%
# 绘制 history_1
plot_accuracies(history_1)
plot_log_loss(history_1)

# %%
# 绘制 history_2
plot_accuracies(history_2)
plot_log_loss(history_2)

# %%
# Accuracy comparison of different models on CIFAR-10
# Data for model 0
test_acc_0 = [x['test_acc'] for x in history_0]
train_acc_0 = [x.get('train_acc') for x in history_0]

# Data for model 1
test_acc_1 = [x['test_acc'] for x in history_1]
train_acc_1 = [x.get('train_acc') for x in history_1]

# Data for model 2
test_acc_2 = [x['test_acc'] for x in history_2]
train_acc_2 = [x.get('train_acc') for x in history_2]

# Plotting
plt.figure(figsize=(12, 8))

# Model 0
plt.plot(train_acc_0, label='num_block = 7 (Train)', color='blue', linestyle='-')
plt.plot(test_acc_0, label='num_block = 7 (Test)', color='blue', linestyle='--')

# Model 1
plt.plot(train_acc_1, label='num_block = 8 (Train)', color='green', linestyle='-')
plt.plot(test_acc_1, label='num_block = 8 (Test)', color='green', linestyle='--')

# Model 2
plt.plot(train_acc_2, label='num_block = 9 (Train)', color='red', linestyle='-')
plt.plot(test_acc_2, label='num_block = 9 (Test)', color='red', linestyle='--')

plt.title('Training and Testing Accuracy with Different Model Structure')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.savefig('./figures/accuracy_different_structure.pdf', dpi=300)
plt.show()

# %% [markdown]
# ### (3) 加载最优模型 & 计算精确率

# %%
# 恢复模型状态
checkpoint = torch.load(best_model_path_0)
model_0.load_state_dict(checkpoint['model_state_dict'])

# 计算精确率
average_precision(model_0, test_loader, classes)
# Out:
# Precision of class airplane: 	0.9215
# Precision of class automobile: 	0.9583
# Precision of class bird: 	0.8899
# Precision of class cat: 	0.8081
# Precision of class deer: 	0.9140
# Precision of class dog: 	0.8590
# Precision of class frog: 	0.9273
# Precision of class horse: 	0.9424
# Precision of class ship: 	0.9482
# Precision of class truck: 	0.9405
# The Average precision value is 0.9109

# %%
# 恢复模型状态
checkpoint = torch.load(best_model_path_1)
model_1.load_state_dict(checkpoint['model_state_dict'])

# 计算精确率
average_precision(model_1, test_loader, classes)
# Out:
# Precision of class airplane: 	0.9031
# Precision of class automobile: 	0.9592
# Precision of class bird: 	0.8214
# Precision of class cat: 	0.7488
# Precision of class deer: 	0.8470
# Precision of class dog: 	0.9118
# Precision of class frog: 	0.9041
# Precision of class horse: 	0.8692
# Precision of class ship: 	0.9328
# Precision of class truck: 	0.9383
# The Average precision value is 0.8836

# %%
# 恢复模型状态
checkpoint = torch.load(best_model_path_2)
model_2.load_state_dict(checkpoint['model_state_dict'])

# 计算精确率
average_precision(model_2, test_loader, classes)
# Out:
# Precision of class airplane: 	0.8921
# Precision of class automobile: 	0.9330
# Precision of class bird: 	0.8971
# Precision of class cat: 	0.7933
# Precision of class deer: 	0.9317
# Precision of class dog: 	0.8281
# Precision of class frog: 	0.8868
# Precision of class horse: 	0.9370
# Precision of class ship: 	0.9586
# Precision of class truck: 	0.9506
# The Average precision value is 0.9008

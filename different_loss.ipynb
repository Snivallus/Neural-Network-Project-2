# %% [markdown]
# ## 1.准备阶段
# 训练数据集 `train_set` 以及测试数据集 `test_set`
# 创建 `train_loader` 和 `test_loader` 用于训练以及测试过程的数据加载

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import torchvision
import torchvision.transforms as transforms
import torch

# PyTorch device
print("CUDA Device Count:", torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    print(f"Device {i} Name:", torch.cuda.get_device_name(i))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"正在使用的是: {device}")

# 创建一个transform, 将 PIL 图片转换为 Tensor
transform = transforms.Compose([
    transforms.ToTensor()
])

# 自定义的帮助函数
from utils.helper_functions import * 

# 下载并加载 CIFAR-10 训练集
# root: 数据集存放路径 (如果路径不存在会自动创建)
# train=True: 指明要加载训练集
# download=True: 如果本地没有, 会自动从网络下载
# transform=transform: 对每张图片应用上面定义的 transform (即 ToTensor)
CIFAR10_trainset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# 同理, 下载并加载 CIFAR-10 测试集
# train=False: 指明要加载测试集
CIFAR10_testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# 调用 get_stats 计算训练集的通道均值和标准差
CIFAR_MEAN_TRAIN, CIFAR_STD_TRAIN = get_stats(CIFAR10_trainset)
print(f"CIFAR Train Set Mean: {CIFAR_MEAN_TRAIN[0]:.4f}, {CIFAR_MEAN_TRAIN[1]:.4f}, {CIFAR_MEAN_TRAIN[2]:.4f}")
print(f"CIFAR Train Set Std: {CIFAR_STD_TRAIN[0]:.4f}, {CIFAR_STD_TRAIN[1]:.4f}, {CIFAR_STD_TRAIN[2]:.4f}")

# 调用 get_stats 计算测试集的通道均值和标准差
CIFAR_MEAN_TEST, CIFAR_STD_TEST = get_stats(CIFAR10_testset)
print(f"CIFAR Test Set Mean: {CIFAR_MEAN_TEST[0]:.4f}, {CIFAR_MEAN_TEST[1]:.4f}, {CIFAR_MEAN_TEST[2]:.4f}")
print(f"CIFAR Test Set Std: {CIFAR_STD_TEST[0]:.4f}, {CIFAR_STD_TEST[1]:.4f}, {CIFAR_STD_TEST[2]:.4f}")
# Out:
# CUDA Device Count: 1
# Device 0 Name: NVIDIA RTX A6000
# 正在使用的是: cuda
# CIFAR Train Set Mean: 0.4914, 0.4822, 0.4465
# CIFAR Train Set Std: 0.2470, 0.2435, 0.2616
# CIFAR Test Set Mean: 0.4942, 0.4851, 0.4504
# CIFAR Test Set Std: 0.2467, 0.2429, 0.2616

# %%
import numpy as np
import random
from torch.utils.data import ConcatDataset

# Set seed
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
     torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Data transforms (normalization & data augmentation)
STATS_TRAIN = (CIFAR_MEAN_TRAIN, CIFAR_STD_TRAIN)
STATS_TEST = (CIFAR_MEAN_TEST, CIFAR_STD_TEST)
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(*STATS_TRAIN),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*STATS_TEST)
])

# PyTorch datasets
train_set = torchvision.datasets.CIFAR10(
    root='./data', 
    train=True, 
    download=True, 
    transform=train_transform
)
test_set = torchvision.datasets.CIFAR10(
    root='./data', 
    train=False, 
    download=True, 
    transform=test_transform
)

classes = train_set.classes
print(classes)

batch_size = 256
train_set_doubled = ConcatDataset([train_set, train_set])
train_loader = torch.utils.data.DataLoader(
    train_set_doubled, 
    batch_size=batch_size, 
    shuffle=True, 
    pin_memory=True, # 异步复制
    num_workers=2
)
train_loader = DeviceDataLoader(train_loader, device)

test_loader = torch.utils.data.DataLoader(
    test_set, 
    batch_size=batch_size*2, 
    shuffle=False, 
    pin_memory=True, # 异步复制
    num_workers=2
)
test_loader = DeviceDataLoader(test_loader, device)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

# Assuming train_loader and classes have been defined
print("显示一些训练图像:")
show_batch_images(
    train_loader, 
    classes, 
    batch_size, 
    CIFAR_MEAN_TRAIN, 
    CIFAR_STD_TRAIN
)

print("显示一些测试图像:")
show_batch_images(
    test_loader, 
    classes, 
    batch_size, 
    CIFAR_MEAN_TEST, 
    CIFAR_STD_TEST
)
# Out:
# 显示一些训练图像:
# Labels: frog  cat   cat   deer  cat   ship  automobile bird  ship  dog   airplane automobile dog   deer  horse frog  frog  airplane deer  frog  automobile cat   dog   ship  dog   frog  automobile bird  frog  automobile frog  automobile cat   dog   deer  automobile automobile ship  frog  cat   automobile cat   cat   deer  dog   truck deer  deer  automobile automobile dog   bird  frog  bird  cat   deer  automobile ship  cat   bird  dog   cat   dog   automobile airplane deer  cat   truck deer  ship  dog   dog   ship  cat   automobile frog  automobile frog  horse horse dog   bird  truck cat   truck ship  airplane ship  airplane airplane dog   automobile cat   frog  dog   bird  ship  automobile bird  bird  airplane bird  horse truck horse truck ship  frog  dog   airplane ship  bird  horse ship  automobile horse automobile dog   ship  ship  bird  frog  bird  bird  deer  automobile airplane bird  horse ship  deer  ship  dog   airplane ship  ship  airplane airplane deer  ship  horse airplane bird  ship  ship  automobile cat   frog  ship  frog  ship  bird  cat   horse frog  automobile automobile deer  dog   automobile cat   ship  deer  automobile bird  airplane truck deer  automobile dog   airplane horse cat   ship  frog  frog  deer  deer  ship  horse frog  cat   bird  ship  truck frog  horse deer  horse airplane horse horse bird  cat   cat   deer  dog   truck airplane deer  airplane frog  frog  truck automobile deer  truck frog  bird  frog  frog  horse truck deer  ship  bird  frog  horse frog  airplane truck dog   frog  bird  airplane truck horse deer  frog  truck ship  horse dog   frog  deer  dog   airplane automobile dog   airplane airplane truck automobile truck cat   bird  bird  cat   cat   ship  ship  horse ship  automobile automobile airplane
# 显示一些测试图像:
# Labels: cat   ship  ship  airplane frog  frog  automobile frog  cat   automobile airplane truck dog   horse truck ship  dog   horse ship  frog  horse airplane deer  truck dog   bird  deer  airplane truck frog  frog  dog   deer  dog   truck bird  deer  automobile truck dog   deer  frog  dog   frog  airplane truck cat   truck horse frog  truck ship  airplane cat   ship  ship  horse horse deer  frog  horse cat   frog  cat   frog  bird  automobile bird  cat   horse bird  frog  ship  ship  airplane bird  truck cat   cat   ship  ship  automobile automobile horse bird  dog   bird  horse ship  truck airplane cat   ship  frog  deer  frog  frog  airplane airplane horse deer  dog   frog  cat   automobile automobile cat   frog  ship  horse deer  airplane frog  bird  automobile cat   airplane deer  bird  horse ship  cat   automobile bird  ship  airplane ship  cat   dog   bird  deer  automobile ship  truck automobile bird  truck horse bird  truck frog  dog   frog  cat   ship  horse frog  bird  dog   bird  ship  truck frog  airplane airplane dog   bird  truck dog   deer  bird  automobile frog  frog  ship  deer  ship  deer  dog   airplane truck truck truck ship  truck truck cat   horse dog   airplane airplane dog   bird  bird  cat   ship  frog  cat   deer  airplane dog   ship  airplane automobile horse bird  ship  ship  horse ship  dog   automobile ship  horse automobile cat   airplane dog   horse truck horse deer  dog   truck ship  airplane horse truck ship  bird  horse frog  truck deer  cat   truck frog  deer  horse frog  dog   automobile dog   ship  ship  airplane deer  airplane dog   dog   automobile automobile ship  truck airplane cat   automobile truck bird  bird  dog   cat   truck truck deer  airplane

# %% [markdown]
# ## 2.创建分类器

# %%
model_0 = to_device(CNN_model(), device)
# print(model_0)

# 输出模型的参数量、FLOPs、所占空间大小
model_info(model_0, device)
# Out:
# 模型参数量为: 773842
# FLOPs: 0.114 GFLOPs
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.84
# Params size (MB): 2.95
# Estimated Total Size (MB): 15.80

# %%
model_1 = to_device(CNN_model(), device)
# print(model_1)

# 输出模型的参数量、FLOPs、所占空间大小
model_info(model_1, device)
# Out:
# 模型参数量为: 773842
# FLOPs: 0.114 GFLOPs
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.84
# Params size (MB): 2.95
# Estimated Total Size (MB): 15.80

# %%
model_2 = to_device(CNN_model(), device)
# print(model_2)

# 输出模型的参数量、FLOPs、所占空间大小
model_info(model_2, device)
# Out:
# 模型参数量为: 773842
# FLOPs: 0.114 GFLOPs
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.84
# Params size (MB): 2.95
# Estimated Total Size (MB): 15.80

# %% [markdown]
# ## 3.训练

# %%
# 设置超参数
epochs = 100
warmup_epochs = 5
max_lr = 0.001
grad_clip = 1
# 提前停止策略的参数
patience = 10
min_delta = 0.0001

# %%
# 最优模型的保存路径
best_model_path_0 = "./saved_weights/different_loss/best_model_0.pth"
weight_decay_0 = 1e-6

# 检查目录是否存在, 如果不存在, 则创建
if not os.path.exists(os.path.dirname(best_model_path_0)):
    os.makedirs(os.path.dirname(best_model_path_0))

# 计算并输出初始模型(未训练前)的性能
history_0 = [evaluate(model_0, test_loader)]
print(history_0)

# 进行训练
history_0 += fit_with_warmup_adam(
    epochs, max_lr, model_0, train_loader, test_loader,
    weight_decay=weight_decay_0,
    grad_clip=grad_clip,
    warmup_epochs=warmup_epochs,
    best_model_path=best_model_path_0,
    patience=patience,
    min_delta=min_delta
)
# Out:
# [{'test_loss': 2.3029985427856445, 'test_acc': 0.10032743215560913}]
# Epoch [1], learning_rate: 0.00020, train_loss: 2.2071, train_acc: 0.1503, test_loss: 1.9193, test_acc: 0.2573
# New best model saved at epoch 1 with accuracy 0.2573
# Epoch [2], learning_rate: 0.00040, train_loss: 1.8365, train_acc: 0.3084, test_loss: 1.6505, test_acc: 0.3910
# New best model saved at epoch 2 with accuracy 0.3910
# Epoch [3], learning_rate: 0.00060, train_loss: 1.5632, train_acc: 0.4351, test_loss: 1.4899, test_acc: 0.4820
# New best model saved at epoch 3 with accuracy 0.4820
# Epoch [4], learning_rate: 0.00080, train_loss: 1.3198, train_acc: 0.5325, test_loss: 1.1678, test_acc: 0.5803
# New best model saved at epoch 4 with accuracy 0.5803
# Epoch [5], learning_rate: 0.00100, train_loss: 1.1260, train_acc: 0.6062, test_loss: 1.0857, test_acc: 0.6245
# New best model saved at epoch 5 with accuracy 0.6245
# Epoch [6], learning_rate: 0.00100, train_loss: 0.9261, train_acc: 0.6784, test_loss: 0.8416, test_acc: 0.7030
# New best model saved at epoch 6 with accuracy 0.7030
# Epoch [7], learning_rate: 0.00100, train_loss: 0.8485, train_acc: 0.7107, test_loss: 0.8029, test_acc: 0.7204
# New best model saved at epoch 7 with accuracy 0.7204
# Epoch [8], learning_rate: 0.00100, train_loss: 0.7867, train_acc: 0.7331, test_loss: 0.8596, test_acc: 0.7072
# Epoch [9], learning_rate: 0.00100, train_loss: 0.7361, train_acc: 0.7504, test_loss: 0.7026, test_acc: 0.7674
# New best model saved at epoch 9 with accuracy 0.7674
# Epoch [10], learning_rate: 0.00100, train_loss: 0.6890, train_acc: 0.7684, test_loss: 0.7220, test_acc: 0.7543
# Epoch [11], learning_rate: 0.00100, train_loss: 0.6395, train_acc: 0.7861, test_loss: 0.6830, test_acc: 0.7732
# New best model saved at epoch 11 with accuracy 0.7732
# Epoch [12], learning_rate: 0.00100, train_loss: 0.6009, train_acc: 0.7972, test_loss: 0.7832, test_acc: 0.7470
# Epoch [13], learning_rate: 0.00100, train_loss: 0.5649, train_acc: 0.8117, test_loss: 0.6408, test_acc: 0.7857
# New best model saved at epoch 13 with accuracy 0.7857
# Epoch [14], learning_rate: 0.00100, train_loss: 0.5382, train_acc: 0.8208, test_loss: 0.5698, test_acc: 0.8093
# New best model saved at epoch 14 with accuracy 0.8093
# Epoch [15], learning_rate: 0.00100, train_loss: 0.4972, train_acc: 0.8332, test_loss: 0.6481, test_acc: 0.7908
# Epoch [16], learning_rate: 0.00100, train_loss: 0.4715, train_acc: 0.8415, test_loss: 0.5259, test_acc: 0.8238
# New best model saved at epoch 16 with accuracy 0.8238
# Epoch [17], learning_rate: 0.00100, train_loss: 0.4469, train_acc: 0.8508, test_loss: 0.6762, test_acc: 0.7943
# Epoch [18], learning_rate: 0.00100, train_loss: 0.4236, train_acc: 0.8580, test_loss: 0.5375, test_acc: 0.8279
# New best model saved at epoch 18 with accuracy 0.8279
# Epoch [19], learning_rate: 0.00100, train_loss: 0.4004, train_acc: 0.8653, test_loss: 0.6129, test_acc: 0.8078
# Epoch [20], learning_rate: 0.00100, train_loss: 0.3787, train_acc: 0.8741, test_loss: 0.4683, test_acc: 0.8507
# New best model saved at epoch 20 with accuracy 0.8507
# Epoch [21], learning_rate: 0.00100, train_loss: 0.3621, train_acc: 0.8796, test_loss: 0.4893, test_acc: 0.8425
# Epoch [22], learning_rate: 0.00100, train_loss: 0.3448, train_acc: 0.8855, test_loss: 0.5136, test_acc: 0.8390
# Epoch [23], learning_rate: 0.00100, train_loss: 0.3303, train_acc: 0.8901, test_loss: 0.5318, test_acc: 0.8368
# Epoch [24], learning_rate: 0.00100, train_loss: 0.3109, train_acc: 0.8966, test_loss: 0.4832, test_acc: 0.8523
# New best model saved at epoch 24 with accuracy 0.8523
# Epoch [25], learning_rate: 0.00100, train_loss: 0.3012, train_acc: 0.9003, test_loss: 0.4601, test_acc: 0.8569
# New best model saved at epoch 25 with accuracy 0.8569
# Epoch [26], learning_rate: 0.00100, train_loss: 0.2890, train_acc: 0.9029, test_loss: 0.5359, test_acc: 0.8334
# Epoch [27], learning_rate: 0.00100, train_loss: 0.2755, train_acc: 0.9076, test_loss: 0.4789, test_acc: 0.8558
# Epoch [28], learning_rate: 0.00100, train_loss: 0.2605, train_acc: 0.9124, test_loss: 0.6307, test_acc: 0.8314
# Epoch [29], learning_rate: 0.00100, train_loss: 0.2573, train_acc: 0.9133, test_loss: 0.4640, test_acc: 0.8562
# Epoch [30], learning_rate: 0.00099, train_loss: 0.2389, train_acc: 0.9190, test_loss: 0.4930, test_acc: 0.8546
# Epoch [31], learning_rate: 0.00099, train_loss: 0.2321, train_acc: 0.9226, test_loss: 0.4142, test_acc: 0.8744
# New best model saved at epoch 31 with accuracy 0.8744
# Epoch [32], learning_rate: 0.00099, train_loss: 0.2212, train_acc: 0.9260, test_loss: 0.4455, test_acc: 0.8664
# Epoch [33], learning_rate: 0.00098, train_loss: 0.2149, train_acc: 0.9279, test_loss: 0.4423, test_acc: 0.8727
# Epoch [34], learning_rate: 0.00097, train_loss: 0.2065, train_acc: 0.9303, test_loss: 0.4995, test_acc: 0.8611
# Epoch [35], learning_rate: 0.00097, train_loss: 0.1962, train_acc: 0.9339, test_loss: 0.5128, test_acc: 0.8568
# Epoch [36], learning_rate: 0.00096, train_loss: 0.1902, train_acc: 0.9363, test_loss: 0.4587, test_acc: 0.8739
# Epoch [37], learning_rate: 0.00095, train_loss: 0.1825, train_acc: 0.9384, test_loss: 0.4349, test_acc: 0.8815
# New best model saved at epoch 37 with accuracy 0.8815
# Epoch [38], learning_rate: 0.00094, train_loss: 0.1759, train_acc: 0.9419, test_loss: 0.4945, test_acc: 0.8670
# Epoch [39], learning_rate: 0.00093, train_loss: 0.1699, train_acc: 0.9431, test_loss: 0.5514, test_acc: 0.8611
# Epoch [40], learning_rate: 0.00092, train_loss: 0.1622, train_acc: 0.9460, test_loss: 0.4607, test_acc: 0.8768
# Epoch [41], learning_rate: 0.00091, train_loss: 0.1564, train_acc: 0.9474, test_loss: 0.4921, test_acc: 0.8697
# Epoch [42], learning_rate: 0.00090, train_loss: 0.1501, train_acc: 0.9501, test_loss: 0.4737, test_acc: 0.8747
# Epoch [43], learning_rate: 0.00089, train_loss: 0.1430, train_acc: 0.9521, test_loss: 0.4584, test_acc: 0.8798
# Epoch [44], learning_rate: 0.00088, train_loss: 0.1414, train_acc: 0.9528, test_loss: 0.4965, test_acc: 0.8722
# Epoch [45], learning_rate: 0.00086, train_loss: 0.1319, train_acc: 0.9564, test_loss: 0.4448, test_acc: 0.8853
# New best model saved at epoch 45 with accuracy 0.8853
# Epoch [46], learning_rate: 0.00085, train_loss: 0.1250, train_acc: 0.9585, test_loss: 0.4497, test_acc: 0.8851
# Epoch [47], learning_rate: 0.00084, train_loss: 0.1217, train_acc: 0.9592, test_loss: 0.4641, test_acc: 0.8844
# Epoch [48], learning_rate: 0.00082, train_loss: 0.1186, train_acc: 0.9606, test_loss: 0.4914, test_acc: 0.8830
# Epoch [49], learning_rate: 0.00081, train_loss: 0.1118, train_acc: 0.9620, test_loss: 0.4598, test_acc: 0.8837
# Epoch [50], learning_rate: 0.00079, train_loss: 0.1084, train_acc: 0.9633, test_loss: 0.4543, test_acc: 0.8866
# New best model saved at epoch 50 with accuracy 0.8866
# Epoch [51], learning_rate: 0.00078, train_loss: 0.1011, train_acc: 0.9662, test_loss: 0.4644, test_acc: 0.8845
# Epoch [52], learning_rate: 0.00076, train_loss: 0.0989, train_acc: 0.9665, test_loss: 0.5271, test_acc: 0.8793
# Epoch [53], learning_rate: 0.00074, train_loss: 0.0956, train_acc: 0.9681, test_loss: 0.4513, test_acc: 0.8890
# New best model saved at epoch 53 with accuracy 0.8890
# Epoch [54], learning_rate: 0.00072, train_loss: 0.0909, train_acc: 0.9691, test_loss: 0.4704, test_acc: 0.8871
# Epoch [55], learning_rate: 0.00071, train_loss: 0.0853, train_acc: 0.9716, test_loss: 0.4757, test_acc: 0.8913
# New best model saved at epoch 55 with accuracy 0.8913
# Epoch [56], learning_rate: 0.00069, train_loss: 0.0825, train_acc: 0.9726, test_loss: 0.5040, test_acc: 0.8841
# Epoch [57], learning_rate: 0.00067, train_loss: 0.0799, train_acc: 0.9738, test_loss: 0.5391, test_acc: 0.8792
# Epoch [58], learning_rate: 0.00065, train_loss: 0.0754, train_acc: 0.9747, test_loss: 0.4846, test_acc: 0.8906
# Epoch [59], learning_rate: 0.00063, train_loss: 0.0728, train_acc: 0.9761, test_loss: 0.5246, test_acc: 0.8901
# Epoch [60], learning_rate: 0.00062, train_loss: 0.0686, train_acc: 0.9774, test_loss: 0.5042, test_acc: 0.8910
# Epoch [61], learning_rate: 0.00060, train_loss: 0.0652, train_acc: 0.9784, test_loss: 0.4674, test_acc: 0.8967
# New best model saved at epoch 61 with accuracy 0.8967
# Epoch [62], learning_rate: 0.00058, train_loss: 0.0621, train_acc: 0.9792, test_loss: 0.5521, test_acc: 0.8876
# Epoch [63], learning_rate: 0.00056, train_loss: 0.0614, train_acc: 0.9794, test_loss: 0.4811, test_acc: 0.8964
# Epoch [64], learning_rate: 0.00054, train_loss: 0.0570, train_acc: 0.9813, test_loss: 0.5033, test_acc: 0.8964
# Epoch [65], learning_rate: 0.00052, train_loss: 0.0542, train_acc: 0.9820, test_loss: 0.5145, test_acc: 0.8922
# Epoch [66], learning_rate: 0.00050, train_loss: 0.0515, train_acc: 0.9830, test_loss: 0.5614, test_acc: 0.8872
# Epoch [67], learning_rate: 0.00048, train_loss: 0.0507, train_acc: 0.9831, test_loss: 0.5470, test_acc: 0.8937
# Epoch [68], learning_rate: 0.00047, train_loss: 0.0474, train_acc: 0.9843, test_loss: 0.5190, test_acc: 0.8932
# Epoch [69], learning_rate: 0.00045, train_loss: 0.0425, train_acc: 0.9859, test_loss: 0.5236, test_acc: 0.8962
# Epoch [70], learning_rate: 0.00043, train_loss: 0.0439, train_acc: 0.9855, test_loss: 0.5266, test_acc: 0.8985
# New best model saved at epoch 70 with accuracy 0.8985
# Epoch [71], learning_rate: 0.00041, train_loss: 0.0407, train_acc: 0.9868, test_loss: 0.5473, test_acc: 0.8923
# Epoch [72], learning_rate: 0.00039, train_loss: 0.0373, train_acc: 0.9878, test_loss: 0.5509, test_acc: 0.8973
# Epoch [73], learning_rate: 0.00038, train_loss: 0.0364, train_acc: 0.9883, test_loss: 0.5320, test_acc: 0.8986
# Epoch [74], learning_rate: 0.00036, train_loss: 0.0347, train_acc: 0.9880, test_loss: 0.5431, test_acc: 0.9009
# New best model saved at epoch 74 with accuracy 0.9009
# Epoch [75], learning_rate: 0.00034, train_loss: 0.0315, train_acc: 0.9897, test_loss: 0.5570, test_acc: 0.8993
# Epoch [76], learning_rate: 0.00032, train_loss: 0.0304, train_acc: 0.9905, test_loss: 0.5674, test_acc: 0.8978
# Epoch [77], learning_rate: 0.00031, train_loss: 0.0304, train_acc: 0.9903, test_loss: 0.5453, test_acc: 0.9014
# New best model saved at epoch 77 with accuracy 0.9014
# Epoch [78], learning_rate: 0.00029, train_loss: 0.0285, train_acc: 0.9907, test_loss: 0.5719, test_acc: 0.9015
# New best model saved at epoch 78 with accuracy 0.9015
# Epoch [79], learning_rate: 0.00028, train_loss: 0.0273, train_acc: 0.9909, test_loss: 0.5448, test_acc: 0.9039
# New best model saved at epoch 79 with accuracy 0.9039
# Epoch [80], learning_rate: 0.00026, train_loss: 0.0253, train_acc: 0.9920, test_loss: 0.5646, test_acc: 0.9010
# Epoch [81], learning_rate: 0.00025, train_loss: 0.0220, train_acc: 0.9928, test_loss: 0.5986, test_acc: 0.8987
# Epoch [82], learning_rate: 0.00024, train_loss: 0.0217, train_acc: 0.9931, test_loss: 0.5937, test_acc: 0.8992
# Epoch [83], learning_rate: 0.00022, train_loss: 0.0213, train_acc: 0.9930, test_loss: 0.6116, test_acc: 0.8981
# Epoch [84], learning_rate: 0.00021, train_loss: 0.0181, train_acc: 0.9941, test_loss: 0.6127, test_acc: 0.8998
# Epoch [85], learning_rate: 0.00020, train_loss: 0.0191, train_acc: 0.9938, test_loss: 0.6045, test_acc: 0.8988
# Epoch [86], learning_rate: 0.00019, train_loss: 0.0184, train_acc: 0.9940, test_loss: 0.6354, test_acc: 0.8978
# Epoch [87], learning_rate: 0.00018, train_loss: 0.0175, train_acc: 0.9942, test_loss: 0.5797, test_acc: 0.9021
# Epoch [88], learning_rate: 0.00017, train_loss: 0.0155, train_acc: 0.9950, test_loss: 0.6179, test_acc: 0.8993
# Epoch [89], learning_rate: 0.00016, train_loss: 0.0153, train_acc: 0.9952, test_loss: 0.6087, test_acc: 0.9031
# Early stopping triggered after epoch 89
# Best accuracy 0.9038602709770203 occurred at epoch 79
# Early stopping——training halted.

# %%
# 最优模型的保存路径
best_model_path_1 = "./saved_weights/different_loss/best_model_1.pth"
weight_decay_1 = 1e-4

# 检查目录是否存在, 如果不存在, 则创建
if not os.path.exists(os.path.dirname(best_model_path_1)):
    os.makedirs(os.path.dirname(best_model_path_1))

# 计算并输出初始模型(未训练前)的性能
history_1 = [evaluate(model_1, test_loader)]
print(history_1)

# 进行训练
history_1 += fit_with_warmup_adam(
    epochs, max_lr, model_1, train_loader, test_loader,
    weight_decay=weight_decay_1,
    grad_clip=grad_clip,
    warmup_epochs=warmup_epochs,
    best_model_path=best_model_path_1,
    patience=patience,
    min_delta=min_delta
)
# Out:
# [{'test_loss': 2.3028557300567627, 'test_acc': 0.1002412661910057}]
# Epoch [1], learning_rate: 0.00020, train_loss: 2.1502, train_acc: 0.1691, test_loss: 1.8914, test_acc: 0.2763
# New best model saved at epoch 1 with accuracy 0.2763
# Epoch [2], learning_rate: 0.00040, train_loss: 1.8184, train_acc: 0.3089, test_loss: 1.6077, test_acc: 0.4033
# New best model saved at epoch 2 with accuracy 0.4033
# Epoch [3], learning_rate: 0.00060, train_loss: 1.5837, train_acc: 0.4236, test_loss: 1.4146, test_acc: 0.4864
# New best model saved at epoch 3 with accuracy 0.4864
# Epoch [4], learning_rate: 0.00080, train_loss: 1.3703, train_acc: 0.5109, test_loss: 1.4987, test_acc: 0.5020
# New best model saved at epoch 4 with accuracy 0.5020
# Epoch [5], learning_rate: 0.00100, train_loss: 1.1849, train_acc: 0.5833, test_loss: 1.0696, test_acc: 0.6226
# New best model saved at epoch 5 with accuracy 0.6226
# Epoch [6], learning_rate: 0.00100, train_loss: 0.9792, train_acc: 0.6586, test_loss: 0.9025, test_acc: 0.6851
# New best model saved at epoch 6 with accuracy 0.6851
# Epoch [7], learning_rate: 0.00100, train_loss: 0.8964, train_acc: 0.6928, test_loss: 0.8195, test_acc: 0.7196
# New best model saved at epoch 7 with accuracy 0.7196
# Epoch [8], learning_rate: 0.00100, train_loss: 0.8324, train_acc: 0.7164, test_loss: 1.2296, test_acc: 0.6096
# Epoch [9], learning_rate: 0.00100, train_loss: 0.7746, train_acc: 0.7383, test_loss: 0.7530, test_acc: 0.7381
# New best model saved at epoch 9 with accuracy 0.7381
# Epoch [10], learning_rate: 0.00100, train_loss: 0.7241, train_acc: 0.7572, test_loss: 0.9886, test_acc: 0.6811
# Epoch [11], learning_rate: 0.00100, train_loss: 0.6827, train_acc: 0.7706, test_loss: 0.8268, test_acc: 0.7252
# Epoch [12], learning_rate: 0.00100, train_loss: 0.6451, train_acc: 0.7837, test_loss: 0.7222, test_acc: 0.7628
# New best model saved at epoch 12 with accuracy 0.7628
# Epoch [13], learning_rate: 0.00100, train_loss: 0.6021, train_acc: 0.7995, test_loss: 0.6184, test_acc: 0.7933
# New best model saved at epoch 13 with accuracy 0.7933
# Epoch [14], learning_rate: 0.00100, train_loss: 0.5678, train_acc: 0.8101, test_loss: 0.7087, test_acc: 0.7790
# Epoch [15], learning_rate: 0.00100, train_loss: 0.5360, train_acc: 0.8224, test_loss: 0.6282, test_acc: 0.7978
# New best model saved at epoch 15 with accuracy 0.7978
# Epoch [16], learning_rate: 0.00100, train_loss: 0.5129, train_acc: 0.8304, test_loss: 0.5772, test_acc: 0.8092
# New best model saved at epoch 16 with accuracy 0.8092
# Epoch [17], learning_rate: 0.00100, train_loss: 0.4874, train_acc: 0.8383, test_loss: 0.5595, test_acc: 0.8169
# New best model saved at epoch 17 with accuracy 0.8169
# Epoch [18], learning_rate: 0.00100, train_loss: 0.4622, train_acc: 0.8472, test_loss: 0.5042, test_acc: 0.8356
# New best model saved at epoch 18 with accuracy 0.8356
# Epoch [19], learning_rate: 0.00100, train_loss: 0.4461, train_acc: 0.8527, test_loss: 0.6118, test_acc: 0.7997
# Epoch [20], learning_rate: 0.00100, train_loss: 0.4254, train_acc: 0.8592, test_loss: 0.6011, test_acc: 0.8042
# Epoch [21], learning_rate: 0.00100, train_loss: 0.4085, train_acc: 0.8645, test_loss: 0.5152, test_acc: 0.8320
# Epoch [22], learning_rate: 0.00100, train_loss: 0.3948, train_acc: 0.8687, test_loss: 0.6556, test_acc: 0.7880
# Epoch [23], learning_rate: 0.00100, train_loss: 0.3732, train_acc: 0.8754, test_loss: 0.5052, test_acc: 0.8367
# New best model saved at epoch 23 with accuracy 0.8367
# Epoch [24], learning_rate: 0.00100, train_loss: 0.3644, train_acc: 0.8784, test_loss: 0.5310, test_acc: 0.8308
# Epoch [25], learning_rate: 0.00100, train_loss: 0.3527, train_acc: 0.8834, test_loss: 0.6828, test_acc: 0.7945
# Epoch [26], learning_rate: 0.00100, train_loss: 0.3374, train_acc: 0.8875, test_loss: 0.6112, test_acc: 0.8205
# Epoch [27], learning_rate: 0.00100, train_loss: 0.3323, train_acc: 0.8899, test_loss: 0.4906, test_acc: 0.8442
# New best model saved at epoch 27 with accuracy 0.8442
# Epoch [28], learning_rate: 0.00100, train_loss: 0.3225, train_acc: 0.8931, test_loss: 0.5713, test_acc: 0.8193
# Epoch [29], learning_rate: 0.00100, train_loss: 0.3089, train_acc: 0.8971, test_loss: 0.5523, test_acc: 0.8327
# Epoch [30], learning_rate: 0.00099, train_loss: 0.3028, train_acc: 0.8993, test_loss: 0.4651, test_acc: 0.8553
# New best model saved at epoch 30 with accuracy 0.8553
# Epoch [31], learning_rate: 0.00099, train_loss: 0.2903, train_acc: 0.9038, test_loss: 0.5765, test_acc: 0.8239
# Epoch [32], learning_rate: 0.00099, train_loss: 0.2873, train_acc: 0.9040, test_loss: 0.4344, test_acc: 0.8613
# New best model saved at epoch 32 with accuracy 0.8613
# Epoch [33], learning_rate: 0.00098, train_loss: 0.2741, train_acc: 0.9088, test_loss: 0.4200, test_acc: 0.8679
# New best model saved at epoch 33 with accuracy 0.8679
# Epoch [34], learning_rate: 0.00097, train_loss: 0.2699, train_acc: 0.9110, test_loss: 0.4880, test_acc: 0.8548
# Epoch [35], learning_rate: 0.00097, train_loss: 0.2630, train_acc: 0.9126, test_loss: 0.4972, test_acc: 0.8564
# Epoch [36], learning_rate: 0.00096, train_loss: 0.2578, train_acc: 0.9147, test_loss: 0.4097, test_acc: 0.8756
# New best model saved at epoch 36 with accuracy 0.8756
# Epoch [37], learning_rate: 0.00095, train_loss: 0.2467, train_acc: 0.9182, test_loss: 0.4591, test_acc: 0.8583
# Epoch [38], learning_rate: 0.00094, train_loss: 0.2420, train_acc: 0.9191, test_loss: 0.3782, test_acc: 0.8767
# New best model saved at epoch 38 with accuracy 0.8767
# Epoch [39], learning_rate: 0.00093, train_loss: 0.2385, train_acc: 0.9211, test_loss: 0.4278, test_acc: 0.8661
# Epoch [40], learning_rate: 0.00092, train_loss: 0.2333, train_acc: 0.9228, test_loss: 0.4413, test_acc: 0.8678
# Epoch [41], learning_rate: 0.00091, train_loss: 0.2219, train_acc: 0.9262, test_loss: 0.3988, test_acc: 0.8742
# Epoch [42], learning_rate: 0.00090, train_loss: 0.2215, train_acc: 0.9265, test_loss: 0.4236, test_acc: 0.8714
# Epoch [43], learning_rate: 0.00089, train_loss: 0.2148, train_acc: 0.9292, test_loss: 0.5659, test_acc: 0.8444
# Epoch [44], learning_rate: 0.00088, train_loss: 0.2108, train_acc: 0.9311, test_loss: 0.4175, test_acc: 0.8808
# New best model saved at epoch 44 with accuracy 0.8808
# Epoch [45], learning_rate: 0.00086, train_loss: 0.2028, train_acc: 0.9332, test_loss: 0.6928, test_acc: 0.8240
# Epoch [46], learning_rate: 0.00085, train_loss: 0.1957, train_acc: 0.9353, test_loss: 0.3700, test_acc: 0.8907
# New best model saved at epoch 46 with accuracy 0.8907
# Epoch [47], learning_rate: 0.00084, train_loss: 0.1862, train_acc: 0.9381, test_loss: 0.3877, test_acc: 0.8794
# Epoch [48], learning_rate: 0.00082, train_loss: 0.1839, train_acc: 0.9379, test_loss: 0.3959, test_acc: 0.8820
# Epoch [49], learning_rate: 0.00081, train_loss: 0.1832, train_acc: 0.9397, test_loss: 0.4245, test_acc: 0.8772
# Epoch [50], learning_rate: 0.00079, train_loss: 0.1765, train_acc: 0.9415, test_loss: 0.4081, test_acc: 0.8824
# Epoch [51], learning_rate: 0.00078, train_loss: 0.1725, train_acc: 0.9425, test_loss: 0.5494, test_acc: 0.8512
# Epoch [52], learning_rate: 0.00076, train_loss: 0.1657, train_acc: 0.9458, test_loss: 0.4257, test_acc: 0.8794
# Epoch [53], learning_rate: 0.00074, train_loss: 0.1631, train_acc: 0.9465, test_loss: 0.3886, test_acc: 0.8898
# Epoch [54], learning_rate: 0.00072, train_loss: 0.1609, train_acc: 0.9473, test_loss: 0.4048, test_acc: 0.8841
# Epoch [55], learning_rate: 0.00071, train_loss: 0.1557, train_acc: 0.9496, test_loss: 0.4460, test_acc: 0.8740
# Epoch [56], learning_rate: 0.00069, train_loss: 0.1472, train_acc: 0.9521, test_loss: 0.4028, test_acc: 0.8843
# Early stopping triggered after epoch 56
# Best accuracy 0.8906652331352234 occurred at epoch 46
# Early stopping——training halted.

# %%
# 最优模型的保存路径
best_model_path_2 = "./saved_weights/different_loss/best_model_2.pth"
weight_decay_2 = 1e-2

# 检查目录是否存在, 如果不存在, 则创建
if not os.path.exists(os.path.dirname(best_model_path_2)):
    os.makedirs(os.path.dirname(best_model_path_2))

# 计算并输出初始模型(未训练前)的性能
history_2 = [evaluate(model_2, test_loader)]
print(history_2)

# 进行训练
history_2 += fit_with_warmup_adam(
    epochs, max_lr, model_2, train_loader, test_loader,
    weight_decay=weight_decay_2,
    grad_clip=grad_clip,
    warmup_epochs=warmup_epochs,
    best_model_path=best_model_path_2,
    patience=patience,
    min_delta=min_delta
)
# Out:
# [{'test_loss': 2.303102970123291, 'test_acc': 0.09989660233259201}]
# Epoch [1], learning_rate: 0.00020, train_loss: 2.2539, train_acc: 0.1389, test_loss: 1.9963, test_acc: 0.2261
# New best model saved at epoch 1 with accuracy 0.2261
# Epoch [2], learning_rate: 0.00040, train_loss: 1.8563, train_acc: 0.2902, test_loss: 1.8051, test_acc: 0.3340
# New best model saved at epoch 2 with accuracy 0.3340
# Epoch [3], learning_rate: 0.00060, train_loss: 1.6440, train_acc: 0.3920, test_loss: 1.6164, test_acc: 0.4076
# New best model saved at epoch 3 with accuracy 0.4076
# Epoch [4], learning_rate: 0.00080, train_loss: 1.4612, train_acc: 0.4794, test_loss: 1.4787, test_acc: 0.4576
# New best model saved at epoch 4 with accuracy 0.4576
# Epoch [5], learning_rate: 0.00100, train_loss: 1.3619, train_acc: 0.5220, test_loss: 1.5805, test_acc: 0.4603
# New best model saved at epoch 5 with accuracy 0.4603
# Epoch [6], learning_rate: 0.00100, train_loss: 1.2887, train_acc: 0.5732, test_loss: 1.5386, test_acc: 0.4897
# New best model saved at epoch 6 with accuracy 0.4897
# Epoch [7], learning_rate: 0.00100, train_loss: 1.3814, train_acc: 0.5583, test_loss: 1.6174, test_acc: 0.5121
# New best model saved at epoch 7 with accuracy 0.5121
# Epoch [8], learning_rate: 0.00100, train_loss: 1.4396, train_acc: 0.5391, test_loss: 1.7834, test_acc: 0.3679
# Epoch [9], learning_rate: 0.00100, train_loss: 1.4581, train_acc: 0.5289, test_loss: 1.7125, test_acc: 0.3836
# Epoch [10], learning_rate: 0.00100, train_loss: 1.4545, train_acc: 0.5267, test_loss: 1.6268, test_acc: 0.4159
# Epoch [11], learning_rate: 0.00100, train_loss: 1.4327, train_acc: 0.5324, test_loss: 1.6075, test_acc: 0.4588
# Epoch [12], learning_rate: 0.00100, train_loss: 1.4162, train_acc: 0.5373, test_loss: 1.9276, test_acc: 0.3522
# Epoch [13], learning_rate: 0.00100, train_loss: 1.4027, train_acc: 0.5451, test_loss: 1.8221, test_acc: 0.3561
# Epoch [14], learning_rate: 0.00100, train_loss: 1.3828, train_acc: 0.5501, test_loss: 1.6474, test_acc: 0.4437
# Epoch [15], learning_rate: 0.00100, train_loss: 1.3707, train_acc: 0.5559, test_loss: 1.9696, test_acc: 0.2975
# Epoch [16], learning_rate: 0.00100, train_loss: 1.3622, train_acc: 0.5628, test_loss: 1.7525, test_acc: 0.4131
# Epoch [17], learning_rate: 0.00100, train_loss: 1.3597, train_acc: 0.5589, test_loss: 1.9199, test_acc: 0.3299
# Early stopping triggered after epoch 17
# Best accuracy 0.5121380686759949 occurred at epoch 7
# Early stopping——training halted.

# %% [markdown]
# ## 4.模型性能

# %% [markdown]
# ### (1) 基础学习率变化

# %%
# 绘制模型基础学习率变化
lr = np.concatenate([x.get('lrs', []) for x in history_0])
plt.plot(lr, '-b')
plt.xlabel('epoch')
plt.ylabel('learning rate')
plt.title('Learning Rate vs. No. of epochs')
# plt.savefig('./figures/learning_rate.pdf')
plt.show()

# %% [markdown]
# ### (2) 准确率

# %%
# 绘制 history_0
plot_accuracies(history_0)
plot_log_loss(history_0)

# %%
# 绘制 history_1
plot_accuracies(history_1)
plot_log_loss(history_1)

# %%
# 绘制 history_2
plot_accuracies(history_2)
plot_log_loss(history_2)

# %%
# Accuracy comparison of different models on CIFAR-10
# Data for model 0
test_acc_0 = [x['test_acc'] for x in history_0]
train_acc_0 = [x.get('train_acc') for x in history_0]

# Data for model 1
test_acc_1 = [x['test_acc'] for x in history_1]
train_acc_1 = [x.get('train_acc') for x in history_1]

# Data for model 2
test_acc_2 = [x['test_acc'] for x in history_2]
train_acc_2 = [x.get('train_acc') for x in history_2]

# Plotting
plt.figure(figsize=(12, 8))

# Model 0
plt.plot(train_acc_0, label='Weight_Decay = 1e-2 (Train)', color='blue', linestyle='-')
plt.plot(test_acc_0, label='Weight_Decay = 1e-2 (Test)', color='blue', linestyle='--')

# Model 1
plt.plot(train_acc_1, label='Weight_Decay = 1e-4 (Train)', color='green', linestyle='-')
plt.plot(test_acc_1, label='Weight_Decay = 1e-4 (Test)', color='green', linestyle='--')

# Model 2
plt.plot(train_acc_2, label='Weight_Decay = 1e-6 (Train)', color='red', linestyle='-')
plt.plot(test_acc_2, label='Weight_Decay = 1e-6 (Test)', color='red', linestyle='--')

plt.title('Training and Testing Accuracy with Different Losses')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.savefig('./figures/accuracy_different_loss.pdf', dpi=300)
plt.show()

# %% [markdown]
# ### (3) 加载最优模型 & 计算精确率

# %%
# 恢复模型状态
checkpoint = torch.load(best_model_path_0)
model_0.load_state_dict(checkpoint['model_state_dict'])

# 计算精确率
average_precision(model_0, test_loader, classes)
# Out:
# Precision of class airplane: 	0.8917
# Precision of class automobile: 	0.9483
# Precision of class bird: 	0.8619
# Precision of class cat: 	0.8403
# Precision of class deer: 	0.8874
# Precision of class dog: 	0.8453
# Precision of class frog: 	0.9239
# Precision of class horse: 	0.9248
# Precision of class ship: 	0.9558
# Precision of class truck: 	0.9598
# The Average precision value is 0.9039

# %%
# 恢复模型状态
checkpoint = torch.load(best_model_path_1)
model_1.load_state_dict(checkpoint['model_state_dict'])

# 计算精确率
average_precision(model_1, test_loader, classes)
# Out:
# Precision of class airplane: 	0.8955
# Precision of class automobile: 	0.9078
# Precision of class bird: 	0.8608
# Precision of class cat: 	0.7768
# Precision of class deer: 	0.8917
# Precision of class dog: 	0.8327
# Precision of class frog: 	0.9237
# Precision of class horse: 	0.9196
# Precision of class ship: 	0.9502
# Precision of class truck: 	0.9595
# The Average precision value is 0.8918

# %%
# 恢复模型状态
checkpoint = torch.load(best_model_path_2)
model_2.load_state_dict(checkpoint['model_state_dict'])

# 计算精确率
average_precision(model_2, test_loader, classes)
# Out:
# Precision of class airplane: 	0.6553
# Precision of class automobile: 	0.7332
# Precision of class bird: 	0.2434
# Precision of class cat: 	0.1754
# Precision of class deer: 	0.4752
# Precision of class dog: 	0.3150
# Precision of class frog: 	0.5326
# Precision of class horse: 	0.7949
# Precision of class ship: 	0.7532
# Precision of class truck: 	0.9093
# The Average precision value is 0.5588

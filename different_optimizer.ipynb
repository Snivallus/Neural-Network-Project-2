# %% [markdown]
# ## 1.准备阶段
# 训练数据集 `train_set` 以及测试数据集 `test_set`
# 创建 `train_loader` 和 `test_loader` 用于训练以及测试过程的数据加载

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import torchvision
import torchvision.transforms as transforms
import torch

# PyTorch device
print("CUDA Device Count:", torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    print(f"Device {i} Name:", torch.cuda.get_device_name(i))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"正在使用的是: {device}")

# 创建一个transform, 将 PIL 图片转换为 Tensor
transform = transforms.Compose([
    transforms.ToTensor()
])

# 自定义的帮助函数
from utils.helper_functions import * 

# 下载并加载 CIFAR-10 训练集
# root: 数据集存放路径 (如果路径不存在会自动创建)
# train=True: 指明要加载训练集
# download=True: 如果本地没有, 会自动从网络下载
# transform=transform: 对每张图片应用上面定义的 transform (即 ToTensor)
CIFAR10_trainset = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

# 同理, 下载并加载 CIFAR-10 测试集
# train=False: 指明要加载测试集
CIFAR10_testset = torchvision.datasets.CIFAR10(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# 调用 get_stats 计算训练集的通道均值和标准差
CIFAR_MEAN_TRAIN, CIFAR_STD_TRAIN = get_stats(CIFAR10_trainset)
print(f"CIFAR Train Set Mean: {CIFAR_MEAN_TRAIN[0]:.4f}, {CIFAR_MEAN_TRAIN[1]:.4f}, {CIFAR_MEAN_TRAIN[2]:.4f}")
print(f"CIFAR Train Set Std: {CIFAR_STD_TRAIN[0]:.4f}, {CIFAR_STD_TRAIN[1]:.4f}, {CIFAR_STD_TRAIN[2]:.4f}")

# 调用 get_stats 计算测试集的通道均值和标准差
CIFAR_MEAN_TEST, CIFAR_STD_TEST = get_stats(CIFAR10_testset)
print(f"CIFAR Test Set Mean: {CIFAR_MEAN_TEST[0]:.4f}, {CIFAR_MEAN_TEST[1]:.4f}, {CIFAR_MEAN_TEST[2]:.4f}")
print(f"CIFAR Test Set Std: {CIFAR_STD_TEST[0]:.4f}, {CIFAR_STD_TEST[1]:.4f}, {CIFAR_STD_TEST[2]:.4f}")
# Out:
# CUDA Device Count: 1
# Device 0 Name: NVIDIA RTX A6000
# 正在使用的是: cuda
# CIFAR Train Set Mean: 0.4914, 0.4822, 0.4465
# CIFAR Train Set Std: 0.2470, 0.2435, 0.2616
# CIFAR Test Set Mean: 0.4942, 0.4851, 0.4504
# CIFAR Test Set Std: 0.2467, 0.2429, 0.2616

# %%
import numpy as np
import random
from torch.utils.data import ConcatDataset

# Set seed
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
     torch.cuda.manual_seed(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Data transforms (normalization & data augmentation)
STATS_TRAIN = (CIFAR_MEAN_TRAIN, CIFAR_STD_TRAIN)
STATS_TEST = (CIFAR_MEAN_TEST, CIFAR_STD_TEST)
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4, padding_mode='reflect'),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(*STATS_TRAIN),
])
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(*STATS_TEST)
])

# PyTorch datasets
train_set = torchvision.datasets.CIFAR10(
    root='./data', 
    train=True, 
    download=True, 
    transform=train_transform
)
test_set = torchvision.datasets.CIFAR10(
    root='./data', 
    train=False, 
    download=True, 
    transform=test_transform
)

classes = train_set.classes
print(classes)

batch_size = 256
train_set_doubled = ConcatDataset([train_set, train_set])
train_loader = torch.utils.data.DataLoader(
    train_set_doubled, 
    batch_size=batch_size, 
    shuffle=True, 
    pin_memory=True, # 异步复制
    num_workers=2
)
train_loader = DeviceDataLoader(train_loader, device)

test_loader = torch.utils.data.DataLoader(
    test_set, 
    batch_size=batch_size*2, 
    shuffle=False, 
    pin_memory=True, # 异步复制
    num_workers=2
)
test_loader = DeviceDataLoader(test_loader, device)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

# Assuming train_loader and classes have been defined
print("显示一些训练图像:")
show_batch_images(
    train_loader, 
    classes, 
    batch_size, 
    CIFAR_MEAN_TRAIN, 
    CIFAR_STD_TRAIN
)

print("显示一些测试图像:")
show_batch_images(
    test_loader, 
    classes, 
    batch_size, 
    CIFAR_MEAN_TEST, 
    CIFAR_STD_TEST
)
# Out:
# 显示一些训练图像:
# Labels: frog  cat   cat   deer  cat   ship  automobile bird  ship  dog   airplane automobile dog   deer  horse frog  frog  airplane deer  frog  automobile cat   dog   ship  dog   frog  automobile bird  frog  automobile frog  automobile cat   dog   deer  automobile automobile ship  frog  cat   automobile cat   cat   deer  dog   truck deer  deer  automobile automobile dog   bird  frog  bird  cat   deer  automobile ship  cat   bird  dog   cat   dog   automobile airplane deer  cat   truck deer  ship  dog   dog   ship  cat   automobile frog  automobile frog  horse horse dog   bird  truck cat   truck ship  airplane ship  airplane airplane dog   automobile cat   frog  dog   bird  ship  automobile bird  bird  airplane bird  horse truck horse truck ship  frog  dog   airplane ship  bird  horse ship  automobile horse automobile dog   ship  ship  bird  frog  bird  bird  deer  automobile airplane bird  horse ship  deer  ship  dog   airplane ship  ship  airplane airplane deer  ship  horse airplane bird  ship  ship  automobile cat   frog  ship  frog  ship  bird  cat   horse frog  automobile automobile deer  dog   automobile cat   ship  deer  automobile bird  airplane truck deer  automobile dog   airplane horse cat   ship  frog  frog  deer  deer  ship  horse frog  cat   bird  ship  truck frog  horse deer  horse airplane horse horse bird  cat   cat   deer  dog   truck airplane deer  airplane frog  frog  truck automobile deer  truck frog  bird  frog  frog  horse truck deer  ship  bird  frog  horse frog  airplane truck dog   frog  bird  airplane truck horse deer  frog  truck ship  horse dog   frog  deer  dog   airplane automobile dog   airplane airplane truck automobile truck cat   bird  bird  cat   cat   ship  ship  horse ship  automobile automobile airplane
# 显示一些测试图像:
# Labels: cat   ship  ship  airplane frog  frog  automobile frog  cat   automobile airplane truck dog   horse truck ship  dog   horse ship  frog  horse airplane deer  truck dog   bird  deer  airplane truck frog  frog  dog   deer  dog   truck bird  deer  automobile truck dog   deer  frog  dog   frog  airplane truck cat   truck horse frog  truck ship  airplane cat   ship  ship  horse horse deer  frog  horse cat   frog  cat   frog  bird  automobile bird  cat   horse bird  frog  ship  ship  airplane bird  truck cat   cat   ship  ship  automobile automobile horse bird  dog   bird  horse ship  truck airplane cat   ship  frog  deer  frog  frog  airplane airplane horse deer  dog   frog  cat   automobile automobile cat   frog  ship  horse deer  airplane frog  bird  automobile cat   airplane deer  bird  horse ship  cat   automobile bird  ship  airplane ship  cat   dog   bird  deer  automobile ship  truck automobile bird  truck horse bird  truck frog  dog   frog  cat   ship  horse frog  bird  dog   bird  ship  truck frog  airplane airplane dog   bird  truck dog   deer  bird  automobile frog  frog  ship  deer  ship  deer  dog   airplane truck truck truck ship  truck truck cat   horse dog   airplane airplane dog   bird  bird  cat   ship  frog  cat   deer  airplane dog   ship  airplane automobile horse bird  ship  ship  horse ship  dog   automobile ship  horse automobile cat   airplane dog   horse truck horse deer  dog   truck ship  airplane horse truck ship  bird  horse frog  truck deer  cat   truck frog  deer  horse frog  dog   automobile dog   ship  ship  airplane deer  airplane dog   dog   automobile automobile ship  truck airplane cat   automobile truck bird  bird  dog   cat   truck truck deer  airplane

# %% [markdown]
# ## 2.创建分类器

# %%
model_0 = to_device(CNN_model(), device)
# print(model_0)

# 输出模型的参数量、FLOPs、所占空间大小
model_info(model_0, device)
# Out:
# 模型参数量为: 773842
# FLOPs: 0.114 GFLOPs
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.84
# Params size (MB): 2.95
# Estimated Total Size (MB): 15.80

# %%
model_1 = to_device(CNN_model(), device)
# print(model_1)

# 输出模型的参数量、FLOPs、所占空间大小
model_info(model_1, device)
# Out:
# 模型参数量为: 773842
# FLOPs: 0.114 GFLOPs
# Input size (MB): 0.01
# Forward/backward pass size (MB): 12.84
# Params size (MB): 2.95
# Estimated Total Size (MB): 15.80

# %% [markdown]
# ## 3.训练

# %%
# 设置超参数
epochs = 100
warmup_epochs = 5
max_lr = 0.001
grad_clip = 1
weight_decay = 1e-4
# 提前停止策略的参数
patience = 10
min_delta = 0.0001

# %%
# 最优模型的保存路径
best_model_path_0 = "./saved_weights/different_structure/best_model_0.pth"

# 检查目录是否存在, 如果不存在, 则创建
if not os.path.exists(os.path.dirname(best_model_path_0)):
    os.makedirs(os.path.dirname(best_model_path_0))

# 计算并输出初始模型(未训练前)的性能
history_0 = [evaluate(model_0, test_loader)]
print(history_0)

# 进行训练
history_0 += fit_with_warmup_adam(
    epochs, max_lr, model_0, train_loader, test_loader,
    weight_decay=weight_decay,
    grad_clip=grad_clip,
    warmup_epochs=warmup_epochs,
    best_model_path=best_model_path_0,
    patience=patience,
    min_delta=min_delta
)
# Out:
# [{'test_loss': 2.3029985427856445, 'test_acc': 0.10032743215560913}]
# Epoch [1], learning_rate: 0.00020, train_loss: 2.1761, train_acc: 0.1637, test_loss: 1.8772, test_acc: 0.2641
# New best model saved at epoch 1 with accuracy 0.2641
# Epoch [2], learning_rate: 0.00040, train_loss: 1.7980, train_acc: 0.3236, test_loss: 1.5653, test_acc: 0.4216
# New best model saved at epoch 2 with accuracy 0.4216
# Epoch [3], learning_rate: 0.00060, train_loss: 1.5271, train_acc: 0.4485, test_loss: 1.3391, test_acc: 0.5111
# New best model saved at epoch 3 with accuracy 0.5111
# Epoch [4], learning_rate: 0.00080, train_loss: 1.3034, train_acc: 0.5379, test_loss: 1.1661, test_acc: 0.5855
# New best model saved at epoch 4 with accuracy 0.5855
# Epoch [5], learning_rate: 0.00100, train_loss: 1.1409, train_acc: 0.6015, test_loss: 1.0139, test_acc: 0.6349
# New best model saved at epoch 5 with accuracy 0.6349
# Epoch [6], learning_rate: 0.00100, train_loss: 0.9434, train_acc: 0.6745, test_loss: 0.9361, test_acc: 0.6760
# New best model saved at epoch 6 with accuracy 0.6760
# Epoch [7], learning_rate: 0.00100, train_loss: 0.8678, train_acc: 0.7041, test_loss: 0.8744, test_acc: 0.7060
# New best model saved at epoch 7 with accuracy 0.7060
# Epoch [8], learning_rate: 0.00100, train_loss: 0.8118, train_acc: 0.7249, test_loss: 0.7930, test_acc: 0.7312
# New best model saved at epoch 8 with accuracy 0.7312
# Epoch [9], learning_rate: 0.00100, train_loss: 0.7668, train_acc: 0.7426, test_loss: 0.7260, test_acc: 0.7514
# New best model saved at epoch 9 with accuracy 0.7514
# Epoch [10], learning_rate: 0.00100, train_loss: 0.7215, train_acc: 0.7581, test_loss: 0.7361, test_acc: 0.7522
# New best model saved at epoch 10 with accuracy 0.7522
# Epoch [11], learning_rate: 0.00100, train_loss: 0.6834, train_acc: 0.7721, test_loss: 0.6655, test_acc: 0.7732
# New best model saved at epoch 11 with accuracy 0.7732
# Epoch [12], learning_rate: 0.00100, train_loss: 0.6431, train_acc: 0.7853, test_loss: 0.6378, test_acc: 0.7821
# New best model saved at epoch 12 with accuracy 0.7821
# Epoch [13], learning_rate: 0.00100, train_loss: 0.6066, train_acc: 0.7976, test_loss: 0.7237, test_acc: 0.7596
# Epoch [14], learning_rate: 0.00100, train_loss: 0.5737, train_acc: 0.8105, test_loss: 0.7143, test_acc: 0.7691
# Epoch [15], learning_rate: 0.00100, train_loss: 0.5426, train_acc: 0.8207, test_loss: 0.6747, test_acc: 0.7734
# Epoch [16], learning_rate: 0.00100, train_loss: 0.5206, train_acc: 0.8276, test_loss: 0.6123, test_acc: 0.8012
# New best model saved at epoch 16 with accuracy 0.8012
# Epoch [17], learning_rate: 0.00100, train_loss: 0.4968, train_acc: 0.8365, test_loss: 0.5172, test_acc: 0.8285
# New best model saved at epoch 17 with accuracy 0.8285
# Epoch [18], learning_rate: 0.00100, train_loss: 0.4771, train_acc: 0.8426, test_loss: 0.5596, test_acc: 0.8126
# Epoch [19], learning_rate: 0.00100, train_loss: 0.4510, train_acc: 0.8524, test_loss: 0.5950, test_acc: 0.8157
# Epoch [20], learning_rate: 0.00100, train_loss: 0.4295, train_acc: 0.8579, test_loss: 0.5311, test_acc: 0.8212
# Epoch [21], learning_rate: 0.00100, train_loss: 0.4128, train_acc: 0.8638, test_loss: 0.5302, test_acc: 0.8293
# New best model saved at epoch 21 with accuracy 0.8293
# Epoch [22], learning_rate: 0.00100, train_loss: 0.4023, train_acc: 0.8675, test_loss: 0.5726, test_acc: 0.8165
# Epoch [23], learning_rate: 0.00100, train_loss: 0.3842, train_acc: 0.8735, test_loss: 0.4909, test_acc: 0.8395
# New best model saved at epoch 23 with accuracy 0.8395
# Epoch [24], learning_rate: 0.00100, train_loss: 0.3671, train_acc: 0.8779, test_loss: 0.4834, test_acc: 0.8421
# New best model saved at epoch 24 with accuracy 0.8421
# Epoch [25], learning_rate: 0.00100, train_loss: 0.3519, train_acc: 0.8834, test_loss: 0.5273, test_acc: 0.8310
# Epoch [26], learning_rate: 0.00100, train_loss: 0.3415, train_acc: 0.8875, test_loss: 0.5019, test_acc: 0.8411
# Epoch [27], learning_rate: 0.00100, train_loss: 0.3305, train_acc: 0.8897, test_loss: 0.4163, test_acc: 0.8620
# New best model saved at epoch 27 with accuracy 0.8620
# Epoch [28], learning_rate: 0.00100, train_loss: 0.3207, train_acc: 0.8944, test_loss: 0.5377, test_acc: 0.8332
# Epoch [29], learning_rate: 0.00100, train_loss: 0.3106, train_acc: 0.8974, test_loss: 0.4880, test_acc: 0.8480
# Epoch [30], learning_rate: 0.00099, train_loss: 0.2984, train_acc: 0.9012, test_loss: 0.4690, test_acc: 0.8499
# Epoch [31], learning_rate: 0.00099, train_loss: 0.2939, train_acc: 0.9027, test_loss: 0.4556, test_acc: 0.8593
# Epoch [32], learning_rate: 0.00099, train_loss: 0.2825, train_acc: 0.9071, test_loss: 0.4357, test_acc: 0.8627
# New best model saved at epoch 32 with accuracy 0.8627
# Epoch [33], learning_rate: 0.00098, train_loss: 0.2720, train_acc: 0.9088, test_loss: 0.5399, test_acc: 0.8415
# Epoch [34], learning_rate: 0.00097, train_loss: 0.2686, train_acc: 0.9120, test_loss: 0.4530, test_acc: 0.8627
# Epoch [35], learning_rate: 0.00097, train_loss: 0.2547, train_acc: 0.9166, test_loss: 0.4112, test_acc: 0.8736
# New best model saved at epoch 35 with accuracy 0.8736
# Epoch [36], learning_rate: 0.00096, train_loss: 0.2532, train_acc: 0.9159, test_loss: 0.4045, test_acc: 0.8744
# New best model saved at epoch 36 with accuracy 0.8744
# Epoch [37], learning_rate: 0.00095, train_loss: 0.2459, train_acc: 0.9180, test_loss: 0.4145, test_acc: 0.8745
# New best model saved at epoch 37 with accuracy 0.8745
# Epoch [38], learning_rate: 0.00094, train_loss: 0.2382, train_acc: 0.9203, test_loss: 0.4655, test_acc: 0.8626
# Epoch [39], learning_rate: 0.00093, train_loss: 0.2327, train_acc: 0.9230, test_loss: 0.4033, test_acc: 0.8738
# Epoch [40], learning_rate: 0.00092, train_loss: 0.2282, train_acc: 0.9242, test_loss: 0.4611, test_acc: 0.8622
# Epoch [41], learning_rate: 0.00091, train_loss: 0.2177, train_acc: 0.9276, test_loss: 0.3851, test_acc: 0.8847
# New best model saved at epoch 41 with accuracy 0.8847
# Epoch [42], learning_rate: 0.00090, train_loss: 0.2154, train_acc: 0.9286, test_loss: 0.5426, test_acc: 0.8465
# Epoch [43], learning_rate: 0.00089, train_loss: 0.2099, train_acc: 0.9305, test_loss: 0.4025, test_acc: 0.8820
# Epoch [44], learning_rate: 0.00088, train_loss: 0.2024, train_acc: 0.9330, test_loss: 0.3928, test_acc: 0.8806
# Epoch [45], learning_rate: 0.00086, train_loss: 0.1973, train_acc: 0.9350, test_loss: 0.3862, test_acc: 0.8823
# Epoch [46], learning_rate: 0.00085, train_loss: 0.1940, train_acc: 0.9357, test_loss: 0.4200, test_acc: 0.8724
# Epoch [47], learning_rate: 0.00084, train_loss: 0.1838, train_acc: 0.9394, test_loss: 0.3884, test_acc: 0.8874
# New best model saved at epoch 47 with accuracy 0.8874
# Epoch [48], learning_rate: 0.00082, train_loss: 0.1787, train_acc: 0.9398, test_loss: 0.4343, test_acc: 0.8753
# Epoch [49], learning_rate: 0.00081, train_loss: 0.1777, train_acc: 0.9414, test_loss: 0.4753, test_acc: 0.8628
# Epoch [50], learning_rate: 0.00079, train_loss: 0.1699, train_acc: 0.9435, test_loss: 0.4019, test_acc: 0.8857
# Epoch [51], learning_rate: 0.00078, train_loss: 0.1637, train_acc: 0.9456, test_loss: 0.4160, test_acc: 0.8825
# Epoch [52], learning_rate: 0.00076, train_loss: 0.1605, train_acc: 0.9472, test_loss: 0.4790, test_acc: 0.8693
# Epoch [53], learning_rate: 0.00074, train_loss: 0.1555, train_acc: 0.9487, test_loss: 0.3831, test_acc: 0.8908
# New best model saved at epoch 53 with accuracy 0.8908
# Epoch [54], learning_rate: 0.00072, train_loss: 0.1507, train_acc: 0.9497, test_loss: 0.3785, test_acc: 0.8938
# New best model saved at epoch 54 with accuracy 0.8938
# Epoch [55], learning_rate: 0.00071, train_loss: 0.1467, train_acc: 0.9519, test_loss: 0.4139, test_acc: 0.8835
# Epoch [56], learning_rate: 0.00069, train_loss: 0.1425, train_acc: 0.9533, test_loss: 0.4372, test_acc: 0.8830
# Epoch [57], learning_rate: 0.00067, train_loss: 0.1388, train_acc: 0.9548, test_loss: 0.4060, test_acc: 0.8829
# Epoch [58], learning_rate: 0.00065, train_loss: 0.1356, train_acc: 0.9560, test_loss: 0.4308, test_acc: 0.8807
# Epoch [59], learning_rate: 0.00063, train_loss: 0.1262, train_acc: 0.9588, test_loss: 0.3877, test_acc: 0.8917
# Epoch [60], learning_rate: 0.00062, train_loss: 0.1256, train_acc: 0.9588, test_loss: 0.4210, test_acc: 0.8896
# Epoch [61], learning_rate: 0.00060, train_loss: 0.1182, train_acc: 0.9609, test_loss: 0.3621, test_acc: 0.9005
# New best model saved at epoch 61 with accuracy 0.9005
# Epoch [62], learning_rate: 0.00058, train_loss: 0.1165, train_acc: 0.9621, test_loss: 0.3948, test_acc: 0.8926
# Epoch [63], learning_rate: 0.00056, train_loss: 0.1131, train_acc: 0.9630, test_loss: 0.3561, test_acc: 0.8995
# Epoch [64], learning_rate: 0.00054, train_loss: 0.1071, train_acc: 0.9651, test_loss: 0.3744, test_acc: 0.8975
# Epoch [65], learning_rate: 0.00052, train_loss: 0.1019, train_acc: 0.9667, test_loss: 0.4000, test_acc: 0.8893
# Epoch [66], learning_rate: 0.00050, train_loss: 0.0978, train_acc: 0.9675, test_loss: 0.3690, test_acc: 0.9006
# New best model saved at epoch 66 with accuracy 0.9006
# Epoch [67], learning_rate: 0.00048, train_loss: 0.0927, train_acc: 0.9691, test_loss: 0.3741, test_acc: 0.8988
# Epoch [68], learning_rate: 0.00047, train_loss: 0.0891, train_acc: 0.9699, test_loss: 0.3812, test_acc: 0.9022
# New best model saved at epoch 68 with accuracy 0.9022
# Epoch [69], learning_rate: 0.00045, train_loss: 0.0859, train_acc: 0.9723, test_loss: 0.3548, test_acc: 0.9035
# New best model saved at epoch 69 with accuracy 0.9035
# Epoch [70], learning_rate: 0.00043, train_loss: 0.0809, train_acc: 0.9736, test_loss: 0.3654, test_acc: 0.9037
# New best model saved at epoch 70 with accuracy 0.9037
# Epoch [71], learning_rate: 0.00041, train_loss: 0.0787, train_acc: 0.9745, test_loss: 0.3705, test_acc: 0.9039
# New best model saved at epoch 71 with accuracy 0.9039
# Epoch [72], learning_rate: 0.00039, train_loss: 0.0729, train_acc: 0.9759, test_loss: 0.3655, test_acc: 0.9074
# New best model saved at epoch 72 with accuracy 0.9074
# Epoch [73], learning_rate: 0.00038, train_loss: 0.0735, train_acc: 0.9761, test_loss: 0.4246, test_acc: 0.8954
# Epoch [74], learning_rate: 0.00036, train_loss: 0.0680, train_acc: 0.9779, test_loss: 0.4115, test_acc: 0.9007
# Epoch [75], learning_rate: 0.00034, train_loss: 0.0632, train_acc: 0.9795, test_loss: 0.3744, test_acc: 0.9103
# New best model saved at epoch 75 with accuracy 0.9103
# Epoch [76], learning_rate: 0.00032, train_loss: 0.0609, train_acc: 0.9804, test_loss: 0.3910, test_acc: 0.9041
# Epoch [77], learning_rate: 0.00031, train_loss: 0.0574, train_acc: 0.9812, test_loss: 0.3859, test_acc: 0.9088
# Epoch [78], learning_rate: 0.00029, train_loss: 0.0556, train_acc: 0.9824, test_loss: 0.3707, test_acc: 0.9089
# Epoch [79], learning_rate: 0.00028, train_loss: 0.0505, train_acc: 0.9837, test_loss: 0.3921, test_acc: 0.9103
# Epoch [80], learning_rate: 0.00026, train_loss: 0.0483, train_acc: 0.9843, test_loss: 0.3878, test_acc: 0.9106
# New best model saved at epoch 80 with accuracy 0.9106
# Epoch [81], learning_rate: 0.00025, train_loss: 0.0459, train_acc: 0.9851, test_loss: 0.4031, test_acc: 0.9094
# Epoch [82], learning_rate: 0.00024, train_loss: 0.0413, train_acc: 0.9870, test_loss: 0.3802, test_acc: 0.9134
# New best model saved at epoch 82 with accuracy 0.9134
# Epoch [83], learning_rate: 0.00022, train_loss: 0.0398, train_acc: 0.9873, test_loss: 0.3940, test_acc: 0.9098
# Epoch [84], learning_rate: 0.00021, train_loss: 0.0396, train_acc: 0.9875, test_loss: 0.3969, test_acc: 0.9114
# Epoch [85], learning_rate: 0.00020, train_loss: 0.0377, train_acc: 0.9882, test_loss: 0.3978, test_acc: 0.9103
# Epoch [86], learning_rate: 0.00019, train_loss: 0.0338, train_acc: 0.9889, test_loss: 0.4075, test_acc: 0.9117
# Epoch [87], learning_rate: 0.00018, train_loss: 0.0323, train_acc: 0.9901, test_loss: 0.4003, test_acc: 0.9148
# New best model saved at epoch 87 with accuracy 0.9148
# Epoch [88], learning_rate: 0.00017, train_loss: 0.0311, train_acc: 0.9899, test_loss: 0.4202, test_acc: 0.9083
# Epoch [89], learning_rate: 0.00016, train_loss: 0.0288, train_acc: 0.9912, test_loss: 0.4135, test_acc: 0.9135
# Epoch [90], learning_rate: 0.00015, train_loss: 0.0259, train_acc: 0.9918, test_loss: 0.4285, test_acc: 0.9152
# New best model saved at epoch 90 with accuracy 0.9152
# Epoch [91], learning_rate: 0.00014, train_loss: 0.0271, train_acc: 0.9913, test_loss: 0.4177, test_acc: 0.9131
# Epoch [92], learning_rate: 0.00013, train_loss: 0.0240, train_acc: 0.9924, test_loss: 0.4301, test_acc: 0.9143
# Epoch [93], learning_rate: 0.00013, train_loss: 0.0232, train_acc: 0.9927, test_loss: 0.4338, test_acc: 0.9122
# Epoch [94], learning_rate: 0.00012, train_loss: 0.0234, train_acc: 0.9927, test_loss: 0.4308, test_acc: 0.9139
# Epoch [95], learning_rate: 0.00011, train_loss: 0.0212, train_acc: 0.9934, test_loss: 0.4134, test_acc: 0.9170
# New best model saved at epoch 95 with accuracy 0.9170
# Epoch [96], learning_rate: 0.00011, train_loss: 0.0200, train_acc: 0.9938, test_loss: 0.4194, test_acc: 0.9161
# Epoch [97], learning_rate: 0.00011, train_loss: 0.0197, train_acc: 0.9939, test_loss: 0.4327, test_acc: 0.9173
# New best model saved at epoch 97 with accuracy 0.9173
# Epoch [98], learning_rate: 0.00010, train_loss: 0.0194, train_acc: 0.9941, test_loss: 0.4259, test_acc: 0.9165
# Epoch [99], learning_rate: 0.00010, train_loss: 0.0189, train_acc: 0.9941, test_loss: 0.4170, test_acc: 0.9173
# Epoch [100], learning_rate: 0.00010, train_loss: 0.0185, train_acc: 0.9943, test_loss: 0.4266, test_acc: 0.9189
# New best model saved at epoch 100 with accuracy 0.9189

# %%
# 最优模型的保存路径
best_model_path_1 = "./saved_weights/different_structure/best_model_1.pth"

# 检查目录是否存在, 如果不存在, 则创建
if not os.path.exists(os.path.dirname(best_model_path_1)):
    os.makedirs(os.path.dirname(best_model_path_1))

# 计算并输出初始模型(未训练前)的性能
history_1 = [evaluate(model_1, test_loader)]
print(history_1)

# 进行训练
history_1 += fit_with_warmup_SGD(
    epochs, max_lr, model_1, train_loader, test_loader,
    weight_decay=weight_decay,
    grad_clip=grad_clip,
    warmup_epochs=warmup_epochs,
    best_model_path=best_model_path_1,
    patience=patience,
    min_delta=min_delta
)
# Out:
# [{'test_loss': 2.3028557300567627, 'test_acc': 0.1002412661910057}]
# Epoch [1], learning_rate: 0.00020, train_loss: 2.3469, train_acc: 0.0991, test_loss: 2.3019, test_acc: 0.0936
# New best model saved at epoch 1 with accuracy 0.0936
# Epoch [2], learning_rate: 0.00040, train_loss: 2.3075, train_acc: 0.1062, test_loss: 2.2893, test_acc: 0.1130
# New best model saved at epoch 2 with accuracy 0.1130
# Epoch [3], learning_rate: 0.00060, train_loss: 2.2889, train_acc: 0.1139, test_loss: 2.2632, test_acc: 0.1474
# New best model saved at epoch 3 with accuracy 0.1474
# Epoch [4], learning_rate: 0.00080, train_loss: 2.2431, train_acc: 0.1432, test_loss: 2.2012, test_acc: 0.1720
# New best model saved at epoch 4 with accuracy 0.1720
# Epoch [5], learning_rate: 0.00100, train_loss: 2.1677, train_acc: 0.1708, test_loss: 2.1448, test_acc: 0.1837
# New best model saved at epoch 5 with accuracy 0.1837
# Epoch [6], learning_rate: 0.00100, train_loss: 2.0886, train_acc: 0.1896, test_loss: 2.0165, test_acc: 0.2183
# New best model saved at epoch 6 with accuracy 0.2183
# Epoch [7], learning_rate: 0.00100, train_loss: 2.0499, train_acc: 0.2020, test_loss: 1.9737, test_acc: 0.2364
# New best model saved at epoch 7 with accuracy 0.2364
# Epoch [8], learning_rate: 0.00100, train_loss: 2.0206, train_acc: 0.2118, test_loss: 1.9356, test_acc: 0.2507
# New best model saved at epoch 8 with accuracy 0.2507
# Epoch [9], learning_rate: 0.00100, train_loss: 1.9933, train_acc: 0.2177, test_loss: 1.9069, test_acc: 0.2697
# New best model saved at epoch 9 with accuracy 0.2697
# Epoch [10], learning_rate: 0.00100, train_loss: 1.9664, train_acc: 0.2282, test_loss: 1.8763, test_acc: 0.2774
# New best model saved at epoch 10 with accuracy 0.2774
# Epoch [11], learning_rate: 0.00100, train_loss: 1.9480, train_acc: 0.2351, test_loss: 1.8518, test_acc: 0.2828
# New best model saved at epoch 11 with accuracy 0.2828
# Epoch [12], learning_rate: 0.00100, train_loss: 1.9283, train_acc: 0.2412, test_loss: 1.8382, test_acc: 0.2869
# New best model saved at epoch 12 with accuracy 0.2869
# Epoch [13], learning_rate: 0.00100, train_loss: 1.9113, train_acc: 0.2488, test_loss: 1.8158, test_acc: 0.2888
# New best model saved at epoch 13 with accuracy 0.2888
# Epoch [14], learning_rate: 0.00100, train_loss: 1.8970, train_acc: 0.2554, test_loss: 1.8040, test_acc: 0.3021
# New best model saved at epoch 14 with accuracy 0.3021
# Epoch [15], learning_rate: 0.00100, train_loss: 1.8837, train_acc: 0.2618, test_loss: 1.7847, test_acc: 0.3069
# New best model saved at epoch 15 with accuracy 0.3069
# Epoch [16], learning_rate: 0.00100, train_loss: 1.8724, train_acc: 0.2664, test_loss: 1.7784, test_acc: 0.3161
# New best model saved at epoch 16 with accuracy 0.3161
# Epoch [17], learning_rate: 0.00100, train_loss: 1.8623, train_acc: 0.2704, test_loss: 1.7622, test_acc: 0.3170
# New best model saved at epoch 17 with accuracy 0.3170
# Epoch [18], learning_rate: 0.00100, train_loss: 1.8495, train_acc: 0.2776, test_loss: 1.7496, test_acc: 0.3207
# New best model saved at epoch 18 with accuracy 0.3207
# Epoch [19], learning_rate: 0.00100, train_loss: 1.8377, train_acc: 0.2827, test_loss: 1.7432, test_acc: 0.3351
# New best model saved at epoch 19 with accuracy 0.3351
# Epoch [20], learning_rate: 0.00100, train_loss: 1.8287, train_acc: 0.2872, test_loss: 1.7279, test_acc: 0.3386
# New best model saved at epoch 20 with accuracy 0.3386
# Epoch [21], learning_rate: 0.00100, train_loss: 1.8187, train_acc: 0.2917, test_loss: 1.7295, test_acc: 0.3376
# Epoch [22], learning_rate: 0.00100, train_loss: 1.8107, train_acc: 0.2969, test_loss: 1.7141, test_acc: 0.3423
# New best model saved at epoch 22 with accuracy 0.3423
# Epoch [23], learning_rate: 0.00100, train_loss: 1.8001, train_acc: 0.3034, test_loss: 1.6998, test_acc: 0.3497
# New best model saved at epoch 23 with accuracy 0.3497
# Epoch [24], learning_rate: 0.00100, train_loss: 1.7899, train_acc: 0.3075, test_loss: 1.6931, test_acc: 0.3533
# New best model saved at epoch 24 with accuracy 0.3533
# Epoch [25], learning_rate: 0.00100, train_loss: 1.7835, train_acc: 0.3099, test_loss: 1.6841, test_acc: 0.3536
# New best model saved at epoch 25 with accuracy 0.3536
# Epoch [26], learning_rate: 0.00100, train_loss: 1.7747, train_acc: 0.3158, test_loss: 1.6683, test_acc: 0.3630
# New best model saved at epoch 26 with accuracy 0.3630
# Epoch [27], learning_rate: 0.00100, train_loss: 1.7654, train_acc: 0.3196, test_loss: 1.6699, test_acc: 0.3621
# Epoch [28], learning_rate: 0.00100, train_loss: 1.7596, train_acc: 0.3223, test_loss: 1.6596, test_acc: 0.3675
# New best model saved at epoch 28 with accuracy 0.3675
# Epoch [29], learning_rate: 0.00100, train_loss: 1.7505, train_acc: 0.3257, test_loss: 1.6416, test_acc: 0.3760
# New best model saved at epoch 29 with accuracy 0.3760
# Epoch [30], learning_rate: 0.00099, train_loss: 1.7406, train_acc: 0.3304, test_loss: 1.6355, test_acc: 0.3763
# New best model saved at epoch 30 with accuracy 0.3763
# Epoch [31], learning_rate: 0.00099, train_loss: 1.7349, train_acc: 0.3339, test_loss: 1.6231, test_acc: 0.3821
# New best model saved at epoch 31 with accuracy 0.3821
# Epoch [32], learning_rate: 0.00099, train_loss: 1.7286, train_acc: 0.3372, test_loss: 1.6119, test_acc: 0.3883
# New best model saved at epoch 32 with accuracy 0.3883
# Epoch [33], learning_rate: 0.00098, train_loss: 1.7237, train_acc: 0.3392, test_loss: 1.6020, test_acc: 0.3903
# New best model saved at epoch 33 with accuracy 0.3903
# Epoch [34], learning_rate: 0.00097, train_loss: 1.7100, train_acc: 0.3466, test_loss: 1.6000, test_acc: 0.3907
# New best model saved at epoch 34 with accuracy 0.3907
# Epoch [35], learning_rate: 0.00097, train_loss: 1.7032, train_acc: 0.3488, test_loss: 1.5939, test_acc: 0.3952
# New best model saved at epoch 35 with accuracy 0.3952
# Epoch [36], learning_rate: 0.00096, train_loss: 1.6922, train_acc: 0.3550, test_loss: 1.5787, test_acc: 0.4000
# New best model saved at epoch 36 with accuracy 0.4000
# Epoch [37], learning_rate: 0.00095, train_loss: 1.6871, train_acc: 0.3593, test_loss: 1.5743, test_acc: 0.4037
# New best model saved at epoch 37 with accuracy 0.4037
# Epoch [38], learning_rate: 0.00094, train_loss: 1.6737, train_acc: 0.3636, test_loss: 1.5576, test_acc: 0.4111
# New best model saved at epoch 38 with accuracy 0.4111
# Epoch [39], learning_rate: 0.00093, train_loss: 1.6669, train_acc: 0.3676, test_loss: 1.5547, test_acc: 0.4115
# New best model saved at epoch 39 with accuracy 0.4115
# Epoch [40], learning_rate: 0.00092, train_loss: 1.6587, train_acc: 0.3721, test_loss: 1.5451, test_acc: 0.4196
# New best model saved at epoch 40 with accuracy 0.4196
# Epoch [41], learning_rate: 0.00091, train_loss: 1.6505, train_acc: 0.3771, test_loss: 1.5336, test_acc: 0.4199
# New best model saved at epoch 41 with accuracy 0.4199
# Epoch [42], learning_rate: 0.00090, train_loss: 1.6354, train_acc: 0.3832, test_loss: 1.5189, test_acc: 0.4238
# New best model saved at epoch 42 with accuracy 0.4238
# Epoch [43], learning_rate: 0.00089, train_loss: 1.6290, train_acc: 0.3859, test_loss: 1.5073, test_acc: 0.4315
# New best model saved at epoch 43 with accuracy 0.4315
# Epoch [44], learning_rate: 0.00088, train_loss: 1.6204, train_acc: 0.3907, test_loss: 1.5009, test_acc: 0.4285
# Epoch [45], learning_rate: 0.00086, train_loss: 1.6112, train_acc: 0.3953, test_loss: 1.4884, test_acc: 0.4355
# New best model saved at epoch 45 with accuracy 0.4355
# Epoch [46], learning_rate: 0.00085, train_loss: 1.6015, train_acc: 0.4001, test_loss: 1.4793, test_acc: 0.4371
# New best model saved at epoch 46 with accuracy 0.4371
# Epoch [47], learning_rate: 0.00084, train_loss: 1.5937, train_acc: 0.4035, test_loss: 1.4683, test_acc: 0.4451
# New best model saved at epoch 47 with accuracy 0.4451
# Epoch [48], learning_rate: 0.00082, train_loss: 1.5851, train_acc: 0.4070, test_loss: 1.4624, test_acc: 0.4501
# New best model saved at epoch 48 with accuracy 0.4501
# Epoch [49], learning_rate: 0.00081, train_loss: 1.5723, train_acc: 0.4100, test_loss: 1.4512, test_acc: 0.4506
# New best model saved at epoch 49 with accuracy 0.4506
# Epoch [50], learning_rate: 0.00079, train_loss: 1.5698, train_acc: 0.4161, test_loss: 1.4442, test_acc: 0.4621
# New best model saved at epoch 50 with accuracy 0.4621
# Epoch [51], learning_rate: 0.00078, train_loss: 1.5609, train_acc: 0.4199, test_loss: 1.4410, test_acc: 0.4565
# Epoch [52], learning_rate: 0.00076, train_loss: 1.5500, train_acc: 0.4234, test_loss: 1.4259, test_acc: 0.4632
# New best model saved at epoch 52 with accuracy 0.4632
# Epoch [53], learning_rate: 0.00074, train_loss: 1.5461, train_acc: 0.4266, test_loss: 1.4258, test_acc: 0.4657
# New best model saved at epoch 53 with accuracy 0.4657
# Epoch [54], learning_rate: 0.00072, train_loss: 1.5367, train_acc: 0.4294, test_loss: 1.4146, test_acc: 0.4715
# New best model saved at epoch 54 with accuracy 0.4715
# Epoch [55], learning_rate: 0.00071, train_loss: 1.5327, train_acc: 0.4354, test_loss: 1.4030, test_acc: 0.4820
# New best model saved at epoch 55 with accuracy 0.4820
# Epoch [56], learning_rate: 0.00069, train_loss: 1.5274, train_acc: 0.4353, test_loss: 1.3961, test_acc: 0.4809
# Epoch [57], learning_rate: 0.00067, train_loss: 1.5174, train_acc: 0.4405, test_loss: 1.3914, test_acc: 0.4821
# New best model saved at epoch 57 with accuracy 0.4821
# Epoch [58], learning_rate: 0.00065, train_loss: 1.5108, train_acc: 0.4423, test_loss: 1.3867, test_acc: 0.4851
# New best model saved at epoch 58 with accuracy 0.4851
# Epoch [59], learning_rate: 0.00063, train_loss: 1.5040, train_acc: 0.4501, test_loss: 1.3729, test_acc: 0.4939
# New best model saved at epoch 59 with accuracy 0.4939
# Epoch [60], learning_rate: 0.00062, train_loss: 1.4979, train_acc: 0.4513, test_loss: 1.3732, test_acc: 0.4853
# Epoch [61], learning_rate: 0.00060, train_loss: 1.4940, train_acc: 0.4519, test_loss: 1.3647, test_acc: 0.4958
# New best model saved at epoch 61 with accuracy 0.4958
# Epoch [62], learning_rate: 0.00058, train_loss: 1.4871, train_acc: 0.4562, test_loss: 1.3607, test_acc: 0.5009
# New best model saved at epoch 62 with accuracy 0.5009
# Epoch [63], learning_rate: 0.00056, train_loss: 1.4840, train_acc: 0.4580, test_loss: 1.3574, test_acc: 0.4980
# Epoch [64], learning_rate: 0.00054, train_loss: 1.4777, train_acc: 0.4609, test_loss: 1.3503, test_acc: 0.5015
# New best model saved at epoch 64 with accuracy 0.5015
# Epoch [65], learning_rate: 0.00052, train_loss: 1.4712, train_acc: 0.4627, test_loss: 1.3444, test_acc: 0.5012
# Epoch [66], learning_rate: 0.00050, train_loss: 1.4688, train_acc: 0.4671, test_loss: 1.3380, test_acc: 0.5044
# New best model saved at epoch 66 with accuracy 0.5044
# Epoch [67], learning_rate: 0.00048, train_loss: 1.4609, train_acc: 0.4688, test_loss: 1.3343, test_acc: 0.5054
# New best model saved at epoch 67 with accuracy 0.5054
# Epoch [68], learning_rate: 0.00047, train_loss: 1.4546, train_acc: 0.4709, test_loss: 1.3284, test_acc: 0.5067
# New best model saved at epoch 68 with accuracy 0.5067
# Epoch [69], learning_rate: 0.00045, train_loss: 1.4529, train_acc: 0.4705, test_loss: 1.3295, test_acc: 0.5092
# New best model saved at epoch 69 with accuracy 0.5092
# Epoch [70], learning_rate: 0.00043, train_loss: 1.4457, train_acc: 0.4734, test_loss: 1.3208, test_acc: 0.5107
# New best model saved at epoch 70 with accuracy 0.5107
# Epoch [71], learning_rate: 0.00041, train_loss: 1.4429, train_acc: 0.4758, test_loss: 1.3180, test_acc: 0.5117
# New best model saved at epoch 71 with accuracy 0.5117
# Epoch [72], learning_rate: 0.00039, train_loss: 1.4380, train_acc: 0.4779, test_loss: 1.3134, test_acc: 0.5182
# New best model saved at epoch 72 with accuracy 0.5182
# Epoch [73], learning_rate: 0.00038, train_loss: 1.4334, train_acc: 0.4809, test_loss: 1.3086, test_acc: 0.5203
# New best model saved at epoch 73 with accuracy 0.5203
# Epoch [74], learning_rate: 0.00036, train_loss: 1.4306, train_acc: 0.4815, test_loss: 1.3066, test_acc: 0.5184
# Epoch [75], learning_rate: 0.00034, train_loss: 1.4299, train_acc: 0.4833, test_loss: 1.3035, test_acc: 0.5214
# New best model saved at epoch 75 with accuracy 0.5214
# Epoch [76], learning_rate: 0.00032, train_loss: 1.4300, train_acc: 0.4823, test_loss: 1.2973, test_acc: 0.5215
# Epoch [77], learning_rate: 0.00031, train_loss: 1.4246, train_acc: 0.4850, test_loss: 1.2961, test_acc: 0.5263
# New best model saved at epoch 77 with accuracy 0.5263
# Epoch [78], learning_rate: 0.00029, train_loss: 1.4233, train_acc: 0.4849, test_loss: 1.2936, test_acc: 0.5238
# Epoch [79], learning_rate: 0.00028, train_loss: 1.4177, train_acc: 0.4882, test_loss: 1.2912, test_acc: 0.5257
# Epoch [80], learning_rate: 0.00026, train_loss: 1.4166, train_acc: 0.4890, test_loss: 1.2880, test_acc: 0.5253
# Epoch [81], learning_rate: 0.00025, train_loss: 1.4148, train_acc: 0.4880, test_loss: 1.2868, test_acc: 0.5282
# New best model saved at epoch 81 with accuracy 0.5282
# Epoch [82], learning_rate: 0.00024, train_loss: 1.4129, train_acc: 0.4893, test_loss: 1.2846, test_acc: 0.5259
# Epoch [83], learning_rate: 0.00022, train_loss: 1.4101, train_acc: 0.4917, test_loss: 1.2844, test_acc: 0.5266
# Epoch [84], learning_rate: 0.00021, train_loss: 1.4054, train_acc: 0.4930, test_loss: 1.2810, test_acc: 0.5286
# New best model saved at epoch 84 with accuracy 0.5286
# Epoch [85], learning_rate: 0.00020, train_loss: 1.4038, train_acc: 0.4936, test_loss: 1.2782, test_acc: 0.5307
# New best model saved at epoch 85 with accuracy 0.5307
# Epoch [86], learning_rate: 0.00019, train_loss: 1.4054, train_acc: 0.4933, test_loss: 1.2799, test_acc: 0.5272
# Epoch [87], learning_rate: 0.00018, train_loss: 1.4034, train_acc: 0.4960, test_loss: 1.2750, test_acc: 0.5311
# New best model saved at epoch 87 with accuracy 0.5311
# Epoch [88], learning_rate: 0.00017, train_loss: 1.3995, train_acc: 0.4945, test_loss: 1.2735, test_acc: 0.5340
# New best model saved at epoch 88 with accuracy 0.5340
# Epoch [89], learning_rate: 0.00016, train_loss: 1.3964, train_acc: 0.4963, test_loss: 1.2712, test_acc: 0.5336
# Epoch [90], learning_rate: 0.00015, train_loss: 1.3989, train_acc: 0.4967, test_loss: 1.2726, test_acc: 0.5369
# New best model saved at epoch 90 with accuracy 0.5369
# Epoch [91], learning_rate: 0.00014, train_loss: 1.3982, train_acc: 0.4967, test_loss: 1.2716, test_acc: 0.5337
# Epoch [92], learning_rate: 0.00013, train_loss: 1.4005, train_acc: 0.4968, test_loss: 1.2684, test_acc: 0.5350
# Epoch [93], learning_rate: 0.00013, train_loss: 1.3946, train_acc: 0.4985, test_loss: 1.2677, test_acc: 0.5334
# Epoch [94], learning_rate: 0.00012, train_loss: 1.3939, train_acc: 0.4999, test_loss: 1.2643, test_acc: 0.5374
# New best model saved at epoch 94 with accuracy 0.5374
# Epoch [95], learning_rate: 0.00011, train_loss: 1.3929, train_acc: 0.5003, test_loss: 1.2648, test_acc: 0.5363
# Epoch [96], learning_rate: 0.00011, train_loss: 1.3933, train_acc: 0.4981, test_loss: 1.2639, test_acc: 0.5368
# Epoch [97], learning_rate: 0.00011, train_loss: 1.3925, train_acc: 0.4988, test_loss: 1.2662, test_acc: 0.5370
# Epoch [98], learning_rate: 0.00010, train_loss: 1.3884, train_acc: 0.4991, test_loss: 1.2651, test_acc: 0.5390
# New best model saved at epoch 98 with accuracy 0.5390
# Epoch [99], learning_rate: 0.00010, train_loss: 1.3866, train_acc: 0.5003, test_loss: 1.2617, test_acc: 0.5384
# Epoch [100], learning_rate: 0.00010, train_loss: 1.3901, train_acc: 0.4986, test_loss: 1.2608, test_acc: 0.5383

# %% [markdown]
# ## 4.模型性能

# %% [markdown]
# ### (1) 基础学习率变化

# %%
# 绘制模型基础学习率变化
lr = np.concatenate([x.get('lrs', []) for x in history_0])
plt.plot(lr, '-b')
plt.xlabel('epoch')
plt.ylabel('learning rate')
plt.title('Learning Rate vs. No. of epochs')
# plt.savefig('./figures/learning_rate.pdf')
plt.show()

# %% [markdown]
# ### (2) 准确率

# %%
# 绘制 history_0
plot_accuracies(history_0)
plot_log_loss(history_0)

# %%
# 绘制 history_1
plot_accuracies(history_1)
plot_log_loss(history_1)

# %%
# Accuracy comparison of different models on CIFAR-10
# Data for model 0
test_acc_0 = [x['test_acc'] for x in history_0]
train_acc_0 = [x.get('train_acc') for x in history_0]

# Data for model 1
test_acc_1 = [x['test_acc'] for x in history_1]
train_acc_1 = [x.get('train_acc') for x in history_1]

# Plotting
plt.figure(figsize=(12, 8))

# Model 0
plt.plot(train_acc_0, label='Adam (Train)', color='blue', linestyle='-')
plt.plot(test_acc_0, label='Adam (Test)', color='blue', linestyle='--')

# Model 1
plt.plot(train_acc_1, label='SGD (Train)', color='green', linestyle='-')
plt.plot(test_acc_1, label='SGD (Test)', color='green', linestyle='--')

plt.title('Training and Testing Accuracy with Different Optimizer')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.savefig('./figures/accuracy_different_optimizer.pdf', dpi=300)
plt.show()

# %% [markdown]
# ### (3) 加载最优模型 & 计算精确率

# %%
# 恢复模型状态
checkpoint = torch.load(best_model_path_0)
model_0.load_state_dict(checkpoint['model_state_dict'])

# 计算精确率
average_precision(model_0, test_loader, classes)
# Out:
# Precision of class airplane: 	0.9366
# Precision of class automobile: 	0.9574
# Precision of class bird: 	0.9160
# Precision of class cat: 	0.8618
# Precision of class deer: 	0.9072
# Precision of class dog: 	0.8344
# Precision of class frog: 	0.9208
# Precision of class horse: 	0.9468
# Precision of class ship: 	0.9712
# Precision of class truck: 	0.9376
# The Average precision value is 0.9190

# %%
# 恢复模型状态
checkpoint = torch.load(best_model_path_1)
model_1.load_state_dict(checkpoint['model_state_dict'])

# 计算精确率
average_precision(model_1, test_loader, classes)
# Out:
# Precision of class airplane: 	0.6242
# Precision of class automobile: 	0.6946
# Precision of class bird: 	0.3738
# Precision of class cat: 	0.3070
# Precision of class deer: 	0.4169
# Precision of class dog: 	0.4212
# Precision of class frog: 	0.5595
# Precision of class horse: 	0.5191
# Precision of class ship: 	0.7304
# Precision of class truck: 	0.6462
# The Average precision value is 0.5293
